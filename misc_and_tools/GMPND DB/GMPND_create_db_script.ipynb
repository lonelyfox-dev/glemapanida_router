# %% [markdown]
# # Скрипт для создания и заполнения БД

# %% [markdown]
# ## Парсинг JSON и формирование sql скрипта

# %%
import pandas as pd
import numpy as np

# %%
import json

# %% [markdown]
# ### Скрип создания базы и переменные БД

# %%
DATABASE_OWNER = 'postgres' # Юзер БД (админ сервера)
ENCODING = 'UTF8' # Выбранная кодировка должна соответствовать кодировке сервера (на всякий случай)
LOCALE = 'ru_RU'

DATABASE_NAME = 'glemapanida'
SCHEMA_NAME = 'router'
TABLE_NAME = 'City'

# %%
create_db_q = f"""CREATE DATABASE {DATABASE_NAME} WITH
OWNER "{DATABASE_OWNER}"
ENCODING '{ENCODING}'
LC_COLLATE = '{LOCALE}.{ENCODING}'
LC_CTYPE = '{LOCALE}.{ENCODING}'
TEMPLATE template0;

\c {DATABASE_NAME};
set client_encoding TO '{ENCODING}';
"""

create_schema_table_q = f"""
CREATE SCHEMA {SCHEMA_NAME}
    CREATE TABLE {TABLE_NAME} (
        id SERIAL PRIMARY KEY,
        name TEXT NOT NULL,
        code TEXT NOT NULL,
        code_yandex TEXT NOT NULL,
        latitude NUMERIC(10, 7) NOT NULL,
        longitude NUMERIC(10, 7) NOT NULL
    );

CREATE INDEX name_code_idx ON {SCHEMA_NAME}.{TABLE_NAME} ((lower(name)), code);
"""

# %% [markdown]
# ### Города, координаты, международные коды

# %%
city_data = pd.read_excel('data/cities.xlsx').drop_duplicates().reset_index(drop=True)
city_data['name'] = city_data['name'].str.strip()
city_data['code'] = city_data['code'].str.strip()

# %%
city_data.head()
# Out:
#             name   latitude  longitude code
# 0       Адыгейск  44.878372  39.190172  ADY
# 1         Майкоп  44.609827  40.100653  MAY
# 2  Горно-Алтайск  51.958268  85.960296  GOA
# 3         Алейск  52.492091  82.779415  ALY
# 4        Барнаул  53.348115  83.779836  BAX

# %%
city_data.isna().any()
# Out:
# name         False
# latitude     False
# longitude    False
# code         False
# dtype: bool

# %%
city_data.dtypes
# Out:
# name          object
# latitude     float64
# longitude    float64
# code          object
# dtype: object

# %%
city_data.shape
# Out:
# (1119, 4)

# %%
city_data = city_data.drop_duplicates(subset=['name'], keep=False).reset_index(drop=True)

# %%
city_data.shape
# Out:
# (1078, 4)

# %% [markdown]
# Потери при удалении одноимённых городов: 41 наименование

# %% [markdown]
# ### Коды яндекса

# %%
with open('data/allYandex.json', 'r', encoding=f'{ENCODING}') as f:
    yac = json.load(f)

# %%
ya_city_code = {
    'name': [],
    'code_yandex': []
}

for country in yac['countries']:
    if country['title'] == 'Россия':
        for region in country['regions']:
            for settlement in region['settlements']:
                if settlement['title'] in city_data.name.unique().tolist():
                    if settlement['title'] in ya_city_code['name']:
                        idx = ya_city_code['name'].index(settlement['title'])
                        del ya_city_code['name'][idx]
                        del ya_city_code['code_yandex'][idx]
                    else:
                        ya_city_code['name'].append(settlement['title'])
                        ya_city_code['code_yandex'].append(settlement['codes']['yandex_code'])

# %%
ya_city_code_df = pd.DataFrame(ya_city_code)

# %%
ya_city_code_df.name.isin(city_data.name.unique().tolist()).sum()
# Out:
# 966

# %% [markdown]
# Потери при удалении... какой-то хуйни: 112 наименований

# %%
city_data[~city_data.name.isin(ya_city_code_df.name.unique().tolist())].name.unique()
# Out:
# array(['Свободный', 'Знаменск', 'Строитель', 'Сельцо', 'Киржач',
#        'Костерево', 'Муром', 'Покров', 'Новохоперск', 'Россошь',
#        'Иваново', 'Комсомольск', 'Родники', 'Шуя', 'Карабулак', 'Саянск',
#        'Черемхово', 'Майский', 'Чегем', 'Гусев', 'Пионерский',
#        'Светлогорск', 'Светлый', 'Белоусово', 'Ермолино', 'Жуков',
#        'Вилючинск', 'Елизово', 'Сосновка', 'Буй', 'Мантурово', 'Нерехта',
#        'Горячий Ключ', 'Артемовск', 'Зеленогорск', 'Сосновоборск',
#        'Щучье', 'Дмитриев', 'Отрадное', 'Пикалево', 'Сосновый Бор',
#        'Козьмодемьянск', 'Ардатов', 'Дубна', 'Ивантеевка', 'Истра',
#        'Королев', 'Куровское', 'Ликино-Дулево', 'Озеры', 'Пущино',
#        'Щелково', 'Полярный', 'Бор', 'Горбатов', 'Городец', 'Заволжье',
#        'Лысково', 'Павлово', 'Первомайск', 'Семенов', 'Боровичи',
#        'Купино', 'Дмитровск', 'Городище', 'Каменка', 'Верещагино',
#        'Горнозаводск', 'Гремячинск', 'Усолье', 'Артем', 'Находка',
#        'Остров', 'Зверево', 'Рыбное', 'Северо-Курильск', 'Артемовский',
#        'Лесной', 'Талица', 'Дигора', 'Ельня', 'Починок', 'Рудня',
#        'Ярцево', 'Буденновск', 'Уварово', 'Вышний Волочек',
#        'Красный Холм', 'Кувшиново', 'Нелидово', 'Кедровый', 'Северск',
#        'Белев', 'Венев', 'Ясногорск', 'Ак-Довурак', 'Чадан', 'Шагонар',
#        'Белоярский', 'Советский', 'Сургут', 'Карабаш', 'Троицк', 'Канаш',
#        'Билибино', 'Верхоянск', 'Ленск', 'Олекминск', 'Удачный',
#        'Курчалой', 'Ачхой-мартан', 'Колтуши'], dtype=object)

# %%
city_data = pd.merge(
    city_data,
    ya_city_code_df,
    how='inner',
    on='name',
    validate='1:1'
)

city_data.head()
# Out:
#             name   latitude  longitude code code_yandex
# 0       Адыгейск  44.878372  39.190172  ADY      c11005
# 1         Майкоп  44.609827  40.100653  MAY       c1093
# 2  Горно-Алтайск  51.958268  85.960296  GOA      c11319
# 3         Алейск  52.492091  82.779415  ALY      c11234
# 4        Барнаул  53.348115  83.779836  BAX        c197

# %% [markdown]
# ### Скрипт вставки данных

# %%
def extract_info(city):
    city_name = city['name']
    city_lat = city.latitude
    city_lon = city.longitude
    city_code = city.code
    city_code_yandex = city.code_yandex
    
    return f"""INSERT INTO {SCHEMA_NAME}.{TABLE_NAME}(name, code, code_yandex, latitude, longitude) VALUES('{city_name}', '{city_code}', '{city_code_yandex}', {city_lat}, {city_lon});
"""

# %%
insert_into_table_q = f"""
""" + ''.join(city_data.apply(extract_info, axis=1).values.tolist())

# %%
query_str = create_db_q + create_schema_table_q + insert_into_table_q

# %%
with open('create_db.sql', 'w', encoding=f'{ENCODING}') as f:
    f.write(query_str)

# %%
with open('create_db.sql', 'r', encoding=f'{ENCODING}') as f:
    print(f.read())
# Out:
# CREATE DATABASE glemapanida WITH
# OWNER "postgres"
# ENCODING 'UTF8'
# LC_COLLATE = 'ru_RU.UTF8'
# LC_CTYPE = 'ru_RU.UTF8'
# TEMPLATE template0;
#
# \c glemapanida;
# set client_encoding TO 'UTF8';
#
# CREATE SCHEMA router
#     CREATE TABLE City (
#         id SERIAL PRIMARY KEY,
#         name TEXT NOT NULL,
#         code TEXT NOT NULL,
#         latitude NUMERIC(10, 7) NOT NULL,
#         longitude NUMERIC(10, 7) NOT NULL
#     );
#
# CREATE INDEX name_code_idx ON router.City ((lower(name)), code);
#
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Адыгейск', 'ADY', 44.8783715, 39.190172);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Майкоп', 'MAY', 44.6098268, 40.1006527);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Горно-Алтайск', 'GOA', 51.9582681, 85.9602957);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Алейск', 'ALY', 52.4920914, 82.7794145);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Барнаул', 'BAX', 53.3481145, 83.7798362);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Белокуриха', 'BEY', 51.9960534, 84.9840343);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Бийск', 'BIK', 52.5393683, 85.2138852);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Горняк', 'GOR', 50.9979032, 81.4643059);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Заринск', 'ZAR', 53.7063495, 84.9314703);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Змеиногорск', 'ZME', 51.1580235, 82.1872476);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Камень-на-Оби', 'KOB', 53.7915454, 81.3545173);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Новоалтайск', 'NAL', 53.4120811, 83.9311249);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Рубцовск', 'RUB', 51.5013075, 81.2077729);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Славгород', 'SLA', 52.9993053, 78.6459674);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Яровое', 'YAR', 52.9251728, 78.5729898);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Белогорск', 'BEL', 50.9212235, 128.4738742);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Благовещенск', 'BQS', 50.2905935, 127.5272186);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Завитинск', 'ZAV', 50.1064678, 129.4392897);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Зея', 'ZEA', 53.7339151, 127.2658079);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Райчихинск', 'RAJ', 49.7941882, 129.4112149);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Свободный', 'SVO', 51.361264, 128.1218995);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сковородино', 'SKO', 53.9871004, 123.943729);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тында', 'TYA', 55.1546401, 124.7468634);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Циолковский', 'TSJ', 51.7624346, 128.121972);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Шимановск', 'SHI', 52.0052856, 127.7006559);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Архангельск', 'ARH', 64.5392985, 40.5170083);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Вельск', 'VEL', 61.0660057, 42.1032858);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Каргополь', 'KAR', 61.5008762, 38.9636415);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Коряжма', 'KOY', 61.2885993, 47.1002315);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Котлас', 'KOS', 61.2529842, 46.6331915);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мезень', 'MEZ', 65.8398386, 44.2531865);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мирный', 'MJZ', 62.7644267, 40.3359976);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Новодвинск', 'NVD', 64.4136023, 40.8208003);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Няндома', 'NYA', 61.6653735, 40.2061699);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Онега', 'ONE', 63.9163966, 38.0805749);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Северодвинск', 'SEV', 64.56253, 39.8182715);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сольвычегодск', 'SOL', 61.3318091, 46.920351);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Шенкурск', 'SHE', 62.1057423, 42.89959);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Астрахань', 'ASF', 46.3655808, 48.0559979);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ахтубинск', 'AHT', 48.2753078, 46.1906741);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Знаменск', 'ZNV', 48.5865618, 45.7367908);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Камызяк', 'KAM', 46.1105429, 48.0732724);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нариманов', 'NRM', 46.6916597, 47.8501624);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Харабали', 'KHA', 47.4089187, 47.2524467);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Агидель', 'AGI', 55.89976, 53.9221149);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Баймак', 'BYM', 52.5912632, 58.3111995);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Белебей', 'BEL', 54.1033832, 54.1111878);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Белорецк', 'BEC', 53.9675927, 58.4099562);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Бирск', 'BIR', 55.4157107, 55.5582335);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Благовещенск', 'BGN', 55.0499592, 55.955309);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Давлеканово', 'DAV', 54.2227617, 55.0313419);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Дюртюли', 'DUR', 55.4848047, 54.8524875);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ишимбай', 'ISH', 53.4546314, 56.043874);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кумертау', 'KUM', 52.7565537, 55.7969915);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Межгорье', 'MEJ', 54.239683, 57.96146);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мелеуз', 'MEE', 52.9590637, 55.9283483);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нефтекамск', 'NEF', 56.0883075, 54.2483391);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Октябрьский', 'OKT', 54.4815344, 53.4656611);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Салават', 'SAL', 53.3616311, 55.9245559);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сибай', 'SIB', 52.7205811, 58.6663303);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Стерлитамак', 'STK', 53.6302498, 55.9315707);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Туймазы', 'TUI', 54.5999889, 53.6949081);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Уфа', 'UFA', 54.734853, 55.9578647);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Учалы', 'UCH', 54.3066965, 59.4126559);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Янаул', 'YAN', 56.2650336, 54.9298314);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Алексеевка', 'ALX', 50.6299932, 38.6881776);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Белгород', 'BLP', 50.5977351, 36.5858236);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Бирюч', 'BIR', 50.6483899, 38.4006203);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Валуйки', 'VAL', 50.2112799, 38.0998765);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Грайворон', 'GRV', 50.4862699, 35.6662957);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Губкин', 'GUB', 51.2836362, 37.5347608);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Короча', 'KRC', 50.8130123, 37.1896543);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Новый Оскол', 'NOS', 50.7635162, 37.8774026);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Старый Оскол', 'STO', 51.2965991, 37.8349849);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Строитель', 'STR', 50.7845571, 36.4886619);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Шебекино', 'SHE', 50.4005506, 36.8877988);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Брянск', 'BRY', 53.2420071, 34.3652716);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Дятьково', 'DYA', 53.5958283, 34.355092);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Жуковка', 'ZHK', 53.5341219, 33.7302166);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Злынка', 'ZLY', 52.4265906, 31.7360386);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Карачев', 'KRC', 53.1297194, 34.9887859);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Клинцы', 'KLI', 52.7529052, 32.2339161);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мглин', 'MGL', 53.0600644, 32.8467217);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Новозыбков', 'NVS', 52.5371426, 31.9356826);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Почеп', 'POC', 52.9154724, 33.4744608);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Севск', 'SEK', 52.1484215, 34.4918198);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сельцо', 'SEL', 53.3738801, 34.1059226);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Стародуб', 'STA', 52.5851881, 32.7603628);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сураж', 'SUR', 53.0171239, 32.3938351);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Трубчевск', 'TRU', 52.5791314, 33.7660013);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Унеча', 'UNE', 52.8460665, 32.6757071);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Фокино', 'FOK', 53.4554552, 34.4158537);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Бабушкин', 'BAB', 51.7113066, 105.8673633);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Гусиноозерск', 'GUS', 51.2865751, 106.5230732);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Закаменск', 'ZAK', 50.3726774, 103.2867452);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кяхта', 'KYA', 50.3466291, 106.4534938);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Северобайкальск', 'SEB', 55.6357165, 109.3362606);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Улан-Удэ', 'UUD', 51.8334378, 107.5841511);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Александров', 'ALA', 56.3919652, 38.711035);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Владимир', 'VLA', 56.1281561, 40.4082995);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Вязники', 'VZN', 56.2976528, 42.2687311);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Гороховец', 'GRH', 56.2021059, 42.692517);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Гусь-Хрустальный', 'GKH', 55.6198065, 40.6578769);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Камешково', 'KAV', 56.3488712, 40.9955682);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Карабаново', 'KAR', 56.3133447, 38.7034267);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Киржач', 'KIR', 56.1485263, 38.8635035);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ковров', 'KVR', 56.3553895, 41.3169568);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кольчугино', 'KOG', 56.3327616, 39.391201);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Костерево', 'KST', 55.9336424, 39.624822);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Курлово', 'KUL', 55.4525994, 40.6124362);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Лакинск', 'LKN', 56.0180614, 39.9564706);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Меленки', 'MEL', 55.3387017, 41.634124);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Муром', 'MUR', 55.5632276, 42.023006);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Петушки', 'PET', 55.9297657, 39.4507913);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Покров', 'POK', 55.9167118, 39.1733641);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Радужный', 'RAD', 55.9961034, 40.3323247);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Собинка', 'SOB', 55.993798, 40.0180034);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Струнино', 'STR', 56.3750001, 38.583938);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Судогда', 'SUD', 55.949897, 40.8563392);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Суздаль', 'SUZ', 56.4273814, 40.4525581);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Юрьев-Польский', 'YUR', 56.4938067, 39.6679311);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Волгоград', 'VOG', 48.7072005, 44.5170207);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Волжский', 'VLS', 48.7978483, 44.7462417);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Дубовка', 'DUB', 49.0555342, 44.8270813);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Жирновск', 'ZHR', 50.9767561, 44.7857694);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Калач-на-Дону', 'KND', 48.6887569, 43.5306866);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Камышин', 'KAM', 50.0651261, 45.3843816);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Котельниково', 'KOT', 47.6310808, 43.1331198);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Котово', 'KOO', 50.3205433, 44.8031864);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Краснослободск', 'KRS', 48.7068777, 44.5631799);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ленинск', 'LEN', 48.6936234, 45.1992835);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Михайловка', 'MIK', 50.0708749, 43.2400847);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Николаевск', 'NIK', 50.0166952, 45.4733204);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Новоаннинский', 'NVA', 50.5296873, 42.6666038);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Палласовка', 'PAL', 50.0501422, 46.8803355);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Петров Вал', 'PTB', 50.1380355, 45.2091455);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Серафимович', 'SER', 49.566286, 42.7360013);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Суровикино', 'SUO', 48.6189756, 42.8541308);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Урюпинск', 'URP', 50.7904767, 42.0288589);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Фролово', 'FRO', 49.7647809, 43.6648936);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Бабаево', 'BAB', 59.389309, 35.9378318);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Белозерск', 'BLZ', 60.0307914, 37.7891123);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Великий Устюг', 'VUS', 60.7603243, 46.3053893);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Вологда', 'VLG', 59.2484186, 39.8356461);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Вытегра', 'VYI', 61.0064157, 36.4495835);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Грязовец', 'GZT', 58.8757657, 40.248477);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кадников', 'KAD', 59.5037947, 40.3440473);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кириллов', 'KRR', 59.8590353, 38.3749854);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Красавино', 'KRV', 60.9613991, 46.481465);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Никольск', 'NKL', 59.5350162, 45.4575468);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сокол', 'SOK', 59.4759156, 40.1114414);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тотьма', 'TOT', 59.9735051, 42.7589701);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Устюжна', 'USH', 58.8383671, 36.4425046);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Харовск', 'KHA', 59.9477728, 40.2000794);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Череповец', 'CHP', 59.1269214, 37.9092243);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Бобров', 'BOB', 51.0902048, 40.0320014);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Богучар', 'BOG', 49.9352997, 40.5592467);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Борисоглебск', 'BOR', 51.3654619, 42.100947);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Бутурлиновка', 'BUT', 50.8313227, 40.5977541);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Воронеж', 'VOZ', 51.6592378, 39.1968284);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Калач', 'KAL', 50.4241213, 41.0162858);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Лиски', 'LIS', 50.9944734, 39.518302);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нововоронеж', 'NVJ', 51.3092463, 39.2162865);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Новохоперск', 'NVX', 51.0953461, 41.6173714);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Острогожск', 'OSK', 50.8678083, 39.0406398);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Павловск', 'PAV', 50.4533684, 40.1369087);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Поворино', 'POV', 51.1953446, 42.2472432);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Россошь', 'RSS', 50.170089, 39.6225534);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Семилуки', 'SMI', 51.6951846, 39.0189797);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Эртиль', 'ERT', 51.831024, 40.8074054);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Буйнакск', 'BUI', 42.8213799, 47.1164452);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Дагестанские Огни', 'DGO', 42.1151021, 48.1939983);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Дербент', 'DER', 42.058935, 48.2908653);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Избербаш', 'IZB', 42.565098, 47.871002);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Каспийск', 'KAS', 42.8916599, 47.6366674);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кизилюрт', 'KZY', 43.2039094, 46.8729311);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кизляр', 'KIZ', 43.8483915, 46.7232828);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Махачкала', 'MCX', 42.9848572, 47.5046303);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Хасавюрт', 'HSR', 43.2505191, 46.5852276);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Южно-Сухокумск', 'YUZ', 44.6600972, 45.6499304);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Биробиджан', 'BJO', 48.7945975, 132.9217594);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Облучье', 'OBU', 49.0188344, 131.0539984);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Балей', 'BAJ', 51.5822063, 116.6380088);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Борзя', 'BAZ', 50.3875437, 116.5235682);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Краснокаменск', 'KAM', 50.092858, 118.0323407);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Могоча', 'MGO', 53.7362465, 119.7661232);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нерчинск', 'NER', 51.9595512, 116.5854018);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Петровск-Забайкальский', 'PBZ', 51.2748381, 108.8467139);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сретенск', 'SRT', 52.2462356, 117.7116971);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Хилок', 'HIL', 51.3635236, 110.458989);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Чита', 'HTA', 52.0340128, 113.4994884);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Шилка', 'SHC', 51.8495302, 116.033575);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Вичуга', 'VCH', 57.2044545, 41.9131192);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Гаврилов Посад', 'GPO', 56.5585967, 40.1228288);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Заволжск', 'ZAV', 57.4916546, 42.1374455);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Иваново', 'IVA', 56.9994677, 40.9728231);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кинешма', 'KNE', 57.4425441, 42.1690039);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Комсомольск', 'KOM', 57.0273907, 40.3775952);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кохма', 'KHM', 56.9325151, 41.0933071);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Наволоки', 'NAV', 57.4678426, 41.9607371);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Плес', 'PLE', 57.4605304, 41.512301);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Приволжск', 'PVI', 57.3807249, 41.2809239);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Пучеж', 'PUC', 56.982075, 43.1683878);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Родники', 'ROD', 57.1024137, 41.7298908);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тейково', 'TEI', 56.8542712, 40.5355289);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Фурманов', 'FUR', 57.2538043, 41.1053808);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Шуя', 'SHU', 56.8560743, 41.3802455);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Южа', 'YUZ', 56.5926458, 42.0457159);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Юрьевец', 'YUR', 57.3178701, 43.1110553);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Карабулак', 'KAR', 43.3054762, 44.9094521);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Магас', 'MAG', 43.1686967, 44.8130849);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Малгобек', 'MAL', 43.5097009, 44.5901517);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Назрань', 'NAZ', 43.2257977, 44.764685);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Алзамай', 'ALZ', 55.5550493, 98.6644106);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ангарск', 'ANG', 52.5448102, 103.8885385);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Байкальск', 'BAI', 51.5231282, 104.1485752);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Бирюсинск', 'BIR', 55.9608611, 97.8203624);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Бодайбо', 'BOD', 57.8468822, 114.1867148);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Братск', 'BRA', 56.1513951, 101.6339892);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Вихоревка', 'VIH', 56.1207708, 101.170332);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Железногорск-Илимский', 'ZHE', 56.5847382, 104.1141747);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Зима', 'ZIM', 53.9206865, 102.0492066);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Иркутск', 'IRT', 52.2863513, 104.280655);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Киренск', 'KIR', 57.7757126, 108.1107766);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нижнеудинск', 'NIZ', 54.8969105, 99.0313481);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Саянск', 'SAY', 54.1107787, 102.1802563);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Свирск', 'SVI', 53.0842576, 103.3364192);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Слюдянка', 'SLY', 51.6562679, 103.7186877);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тайшет', 'TAI', 55.9405397, 98.0030649);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тулун', 'TUL', 54.5571409, 100.5779402);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Усолье-Сибирское', 'USL', 52.7567192, 103.6387694);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Усть-Илимск', 'UIS', 57.9431325, 102.7414683);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Усть-Кут', 'USK', 56.7928049, 105.7756883);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Черемхово', 'CHE', 53.1369385, 103.090119);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Шелехов', 'SHE', 52.2102462, 104.0973531);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Баксан', 'BAK', 43.6820621, 43.5345627);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Майский', 'MAI', 43.6281779, 44.0516663);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нальчик', 'NAL', 43.4846312, 43.6070316);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нарткала', 'NAN', 43.5577208, 43.8576411);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Прохладный', 'PRO', 43.7589521, 44.0101936);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Терек', 'TER', 43.4838439, 44.1402524);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тырныауз', 'TYA', 43.3981939, 42.9215127);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Чегем', 'CHE', 43.5672039, 43.5865338);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Багратионовск', 'BAG', 54.3866976, 20.6418545);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Балтийск', 'BAL', 54.6514128, 19.9141911);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Гвардейск', 'GVA', 54.6588981, 21.0500584);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Гурьевск', 'GUR', 54.7705368, 20.6039109);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Гусев', 'GUS', 54.5915477, 22.1944114);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Зеленоградск', 'ZEL', 54.9600226, 20.4753274);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Калининград', 'KGD', 54.7073218, 20.5072458);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Краснознаменск', 'KZN', 54.9452612, 22.4928511);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ладушкин', 'LAD', 54.5693538, 20.1691909);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мамоново', 'MAM', 54.4645591, 19.9454114);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Неман', 'NEM', 55.0315543, 22.0323961);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нестеров', 'NES', 54.6314454, 22.5713658);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Озерск', 'OZE', 54.4084804, 22.013508);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Пионерский', 'PIO', 54.9516927, 20.227697);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Полесск', 'POL', 54.8626321, 21.0998148);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Правдинск', 'PRA', 54.4430604, 21.0083638);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Приморск', 'PRI', 54.7311185, 19.9983108);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Светлогорск', 'SVE', 54.9439566, 20.1514789);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Светлый', 'SVG', 54.6774051, 20.1356625);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Славск', 'SLA', 55.0451054, 21.6742294);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Советск', 'SOV', 55.0810474, 21.8886272);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Черняховск', 'CHE', 54.6243928, 21.7969179);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Городовиковск', 'GOR', 46.0875351, 41.9354039);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Лагань', 'LAG', 45.3929617, 47.3432943);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Элиста', 'ELS', 46.3082947, 44.2701417);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Балабаново', 'BAL', 55.1773652, 36.6567255);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Белоусово', 'BEL', 55.0957679, 36.6777239);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Боровск', 'BOR', 55.2130965, 36.4927446);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ермолино', 'ERM', 55.1972714, 36.5951966);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Жиздра', 'ZHI', 53.7522384, 34.7386719);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Жуков', 'ZHK', 55.0301386, 36.7393279);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Калуга', 'KLU', 54.5060439, 36.2515933);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Киров', 'KIR', 54.0790823, 34.3077508);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Козельск', 'KOZ', 54.0348417, 35.7807136);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кондрово', 'KND', 54.796051, 35.9276099);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кременки', 'KRE', 54.8863306, 37.116878);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Людиново', 'LUD', 53.8701406, 34.4385498);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Малоярославец', 'MAL', 55.0176756, 36.4632122);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Медынь', 'MED', 54.9690755, 35.887313);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мещовск', 'MES', 54.3191127, 35.2816065);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мосальск', 'MOS', 54.4825589, 34.987206);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Обнинск', 'OBN', 55.0943892, 36.6121785);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сосенский', 'SOS', 54.056525, 35.9621458);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Спас-Деменск', 'SPD', 54.4099201, 34.0190263);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сухиничи', 'SUK', 54.0973787, 35.3443077);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Таруса', 'TAR', 54.7236791, 37.1670866);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Юхнов', 'YUK', 54.7445873, 35.2424857);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Вилючинск', 'VLU', 52.930428, 158.4057276);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Елизово', 'ELI', 53.1829573, 158.3882833);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Петропавловск-Камчатский', 'PKC', 53.0370213, 158.6559142);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Карачаевск', 'KAR', 43.773197, 41.9143726);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Теберда', 'TEB', 43.4438408, 41.7414924);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Усть-Джегута', 'USD', 44.083852, 41.971128);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Черкесск', 'CHK', 44.2268637, 42.0467829);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Беломорск', 'BEM', 64.5378468, 34.7799717);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кемь', 'KEM', 64.9543657, 34.5948547);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кондопога', 'KON', 62.2059866, 34.2681778);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Костомукша', 'KOS', 64.5889946, 30.6015567);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Лахденпохья', 'LAH', 61.5189466, 30.199592);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Медвежьегорск', 'MED', 62.9127678, 34.4567614);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Олонец', 'OLO', 60.9793604, 32.9726031);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Петрозаводск', 'PET', 61.78909, 34.3596263);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Питкяранта', 'PIT', 61.5756886, 31.4641309);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Пудож', 'PUD', 61.8059147, 36.5330088);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сегежа', 'SEG', 63.7437211, 34.3126755);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сортавала', 'SOR', 61.7032216, 30.6917021);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Суоярви', 'SUO', 62.0787769, 32.3499029);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Анжеро-Судженск', 'ANZ', 56.0787179, 86.0202207);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Белово', 'BEL', 54.4221442, 86.3036438);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Березовский', 'BER', 55.6692853, 86.2744636);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Гурьевск', 'GUR', 54.2860005, 85.947723);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Калтан', 'KAL', 53.5210461, 87.2772143);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кемерово', 'KEM', 55.3909721, 86.0467864);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Киселевск', 'KIS', 54.0060382, 86.6367387);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ленинск-Кузнецкий', 'LEN', 54.6674092, 86.1796724);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мариинск', 'MAR', 56.2127836, 87.7454392);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Междуреченск', 'MEZ', 53.6865695, 88.0703888);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мыски', 'MYS', 53.7125516, 87.8056657);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Новокузнецк', 'NOV', 53.7942757, 87.2144046);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Осинники', 'OSI', 53.5987397, 87.3369948);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Полысаево', 'POL', 54.6053968, 86.2808803);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Прокопьевск', 'PRO', 53.8604562, 86.7183428);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Салаир', 'SAL', 54.2351588, 85.8029215);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тайга', 'TAI', 56.0622767, 85.6207907);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Таштагол', 'TAS', 52.7594505, 87.8477272);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Топки', 'TOP', 55.2766036, 85.6153223);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Юрга', 'YUR', 55.7202689, 84.8885516);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Белая Холуница', 'BEL', 58.8415212, 50.8461002);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Вятские Поляны', 'VYA', 56.2286058, 51.0614666);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Зуевка', 'ZUE', 58.4031674, 51.1330787);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Киров', 'KIR', 58.6035313, 49.6679219);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кирово-Чепецк', 'KCH', 58.5559921, 50.0317608);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кирс', 'KRS', 59.3400586, 52.2415895);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Котельнич', 'KOT', 58.3035238, 48.3474288);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Луза', 'LUZ', 60.6290781, 47.2612069);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Малмыж', 'MAL', 56.5243722, 50.6782757);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мураши', 'MUR', 59.3956347, 48.9637651);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нолинск', 'NOL', 57.5596946, 49.9357867);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Омутнинск', 'OMU', 58.6697684, 52.1893554);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Орлов', 'ORL', 58.5389402, 48.8929268);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Слободской', 'SLO', 58.7311934, 50.1670091);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Советск', 'SOV', 57.5841434, 48.9589228);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сосновка', 'SOS', 56.2533149, 51.2833412);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Уржум', 'URJ', 57.1097612, 50.0056278);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Яранск', 'YAR', 57.304195, 47.8479185);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Воркута', 'VOR', 67.4973484, 64.0611045);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Вуктыл', 'VUK', 63.8615209, 57.3165207);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Емва', 'EMB', 62.5965314, 50.8731889);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Инта', 'INT', 66.0368196, 60.1154612);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Микунь', 'MIK', 62.3580188, 50.0719738);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Печора', 'PEC', 65.1485717, 57.22388);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сосногорск', 'SOS', 63.5990137, 53.8762792);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сыктывкар', 'SYK', 61.668789, 50.8356491);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Усинск', 'USI', 65.9941116, 57.5570054);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ухта', 'UKH', 63.5564779, 53.7014202);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Буй', 'BUI', 58.473445, 41.5306746);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Волгореченск', 'VOL', 57.4423712, 41.1593076);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Галич', 'GAL', 58.3826861, 42.3654563);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кологрив', 'KOL', 58.826988, 44.3185323);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кострома', 'KOS', 57.8029445, 40.9907282);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Макарьев', 'MAK', 57.8808916, 43.8014428);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мантурово', 'MAN', 58.3264667, 44.7575036);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нерехта', 'NER', 57.4543706, 40.5725438);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нея', 'NEY', 58.2944499, 43.8780965);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Солигалич', 'SOL', 59.0786729, 42.2877245);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Чухлома', 'CHU', 58.7534246, 42.6883783);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Шарья', 'SHA', 58.3761832, 45.4060762);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Абинск', 'ABI', 44.8679931, 38.1618437);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Анапа', 'ANA', 44.8950777, 37.3163142);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Апшеронск', 'APS', 44.4585239, 39.7300092);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Армавир', 'ARM', 45.0010338, 41.132392);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Белореченск', 'BEL', 44.7652733, 39.8780457);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Геленджик', 'GEL', 44.5631053, 38.0790184);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Горячий Ключ', 'GOR', 44.6343251, 39.1356421);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Гулькевичи', 'GUL', 45.3605769, 40.6918484);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ейск', 'EYS', 46.7114611, 38.2764915);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кореновск', 'KOR', 45.4640868, 39.4590178);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Краснодар', 'KRR', 45.040235, 38.9760801);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кропоткин', 'KRO', 45.4332464, 40.5727852);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Крымск', 'KRY', 44.9344108, 37.9855314);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Курганинск', 'KUG', 44.8876442, 40.5913858);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Лабинск', 'LAB', 44.6353153, 40.724385);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Новокубанск', 'NOX', 45.1038782, 41.0473679);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Новороссийск', 'NOV', 44.7234264, 37.7687218);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Приморско-Ахтарск', 'PRI', 46.0515, 38.1704654);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Славянск-на-Кубани', 'SLA', 45.2605079, 38.1260725);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сочи', 'SOC', 43.5855829, 39.7231419);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Темрюк', 'TEM', 45.2611082, 37.445519);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тимашевск', 'TIM', 45.6159358, 38.9350513);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тихорецк', 'TIH', 45.8546953, 40.1258702);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Туапсе', 'TUA', 44.1103707, 39.082645);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Усть-Лабинск', 'USL', 45.222676, 39.6930239);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Хадыженск', 'KHA', 44.412303, 39.5319151);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Артемовск', 'ART', 54.3472901, 93.4356543);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ачинск', 'ACH', 56.2538662, 90.47949);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Боготол', 'BOG', 56.209881, 89.5300182);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Бородино', 'BOR', 55.9054308, 94.9021138);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Дивногорск', 'DIV', 55.9577868, 92.380085);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Дудинка', 'DUD', 69.4031339, 86.1908135);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Енисейск', 'ENI', 58.4485234, 92.165237);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Железногорск', 'ZHE', 56.2529346, 93.532167);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Заозерный', 'ZAO', 55.9617268, 94.7091037);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Зеленогорск', 'ZEL', 56.1133001, 94.5888736);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Игарка', 'IGA', 67.4667947, 86.5814287);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Иланский', 'ILS', 56.2374163, 96.0672656);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Канск', 'KAN', 56.2049776, 95.7051246);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кодинск', 'KOD', 58.6033961, 99.1797563);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Красноярск', 'KJA', 56.009466, 92.8524162);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Лесосибирск', 'LES', 58.2218201, 92.5036986);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Минусинск', 'MIN', 53.7105509, 91.6871866);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Назарово', 'NAZ', 56.0113176, 90.4167947);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Норильск', 'NOR', 69.3490828, 88.2009965);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сосновоборск', 'SOS', 56.1202088, 93.3353411);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ужур', 'UZH', 55.3141977, 89.8333827);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Уяр', 'UYA', 55.8131698, 94.3282148);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Шарыпово', 'SHA', 55.5389684, 89.1801557);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ялта', 'YAL', 44.416366, 34.04455);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Алушта', 'ALU', 44.6764419, 34.4100387);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Армянск', 'ARM', 46.1059247, 33.6910325);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Бахчисарай', 'BAH', 44.751388, 33.8750341);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Белогорск', 'BEL', 45.0571581, 34.5998775);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Джанкой', 'DJA', 45.7092436, 34.388332);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Евпатория', 'EVP', 45.1904322, 33.3667685);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Керчь', 'KER', 45.3561128, 36.4674285);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Красноперекопск', 'KRA', 45.9537956, 33.7921523);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Саки', 'SAK', 45.1342889, 33.6032508);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Симферополь', 'SIP', 44.9482645, 34.100117);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Старый Крым', 'STC', 45.0290659, 35.0900885);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Судак', 'SUD', 44.8505913, 34.9761591);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Феодосия', 'FEO', 45.031878, 35.3824772);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Щелкино', 'SHC', 45.4289847, 35.8251329);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ялта', 'YAL', 44.4951948, 34.166386);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Далматово', 'DAL', 56.2621393, 62.9387378);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Катайск', 'KAT', 56.2908118, 62.5800669);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Курган', 'KUR', 55.4443448, 65.3161339);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Куртамыш', 'KUT', 54.9368491, 64.4203009);
# ...
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кимовск', 'KIV', 53.9698378, 38.5380267);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Киреевск', 'KIR', 53.9321173, 37.9220791);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Липки', 'LIP', 53.9418109, 37.7019452);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Новомосковск', 'NOV', 54.0109754, 38.2915652);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Плавск', 'PLA', 53.7095993, 37.2863144);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Советск', 'SOV', 53.9337099, 37.6315517);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Суворов', 'SUV', 54.1345367, 36.4806933);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тула', 'TYU', 54.192017, 37.6153885);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Узловая', 'UZL', 53.9731407, 38.1763104);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Чекалин', 'CHE', 54.0985105, 36.2474377);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Щекино', 'SCH', 54.0020749, 37.517686);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ясногорск', 'YAS', 54.4795178, 37.689669);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ак-Довурак', 'AKD', 51.1785658, 90.5984511);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кызыл', 'KYZ', 51.7191542, 94.4377234);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Туран', 'TYA', 52.144932, 93.9172495);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Чадан', 'CAD', 51.2844482, 91.5789135);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Шагонар', 'SHA', 51.5347357, 92.9199618);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Заводоуковск', 'ZAV', 56.5012193, 66.5505094);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ишим', 'ISH', 56.0952037, 69.4643292);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тобольск', 'TOX', 58.2016828, 68.2538392);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тюмень', 'TJM', 57.1530824, 65.5343118);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ялуторовск', 'JAL', 56.649167, 66.297034);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Воткинск', 'VOT', 57.0517641, 53.9874635);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Глазов', 'GLA', 58.1359111, 52.6634998);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ижевск', 'IJK', 56.8527444, 53.2113961);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Камбарка', 'KAM', 56.2659745, 54.1934153);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Можга', 'MOZ', 56.4427219, 52.2138882);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сарапул', 'SAR', 56.4616117, 53.8036967);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Барыш', 'BAR', 53.6534563, 47.1180805);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Димитровград', 'DGR', 54.2168446, 49.6261645);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Инза', 'INZ', 53.8550467, 46.3532786);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Новоульяновск', 'NUL', 54.1447691, 48.3911701);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сенгилей', 'SEN', 53.9590553, 48.7767869);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ульяновск', 'ULY', 54.3080674, 48.3748717);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Амурск', 'AMS', 50.2345017, 136.8791135);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Бикин', 'BIK', 46.8186244, 134.2551046);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Вяземский', 'VYA', 47.5354416, 134.7553701);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Комсомольск-на-Амуре', 'KXN', 50.550011, 137.0079286);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Николаевск-на-Амуре', 'NIK', 53.1461943, 140.7109642);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Советская Гавань', 'SAI', 48.9664554, 140.2852223);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Хабаровск', 'KHV', 48.4647991, 135.0598811);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Абаза', 'ABZ', 52.6517296, 90.0885929);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Абакан', 'ABA', 53.7223661, 91.4437792);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Саяногорск', 'SAY', 53.1008226, 91.4121643);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сорск', 'SOR', 54.0001451, 90.2595674);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Черногорск', 'CHE', 53.8258425, 91.3259669);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Белоярский', 'BEL', 63.712181, 66.6772357);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Когалым', 'KOG', 62.2638914, 74.4828687);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Лангепас', 'LAN', 61.2536667, 75.1807905);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Лянтор', 'LNT', 61.6391639, 72.1793828);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мегион', 'MEG', 61.0318946, 76.1024772);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нефтеюганск', 'NEF', 61.0882837, 72.6164185);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нижневартовск', 'NJV', 60.9397379, 76.5696206);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нягань', 'NYA', 62.1454839, 65.3944361);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Покачи', 'POK', 61.7421977, 75.5942069);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Пыть-Ях', 'PYA', 60.7585769, 72.8366445);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Радужный', 'RAD', 62.1343067, 77.4584346);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Советский', 'SOV', 61.3706695, 63.566863);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сургут', 'SGC', 61.2539773, 73.3961726);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Урай', 'URJ', 60.1295842, 64.8040117);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ханты-Мансийск', 'HMA', 61.0024344, 69.0183322);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Югорск', 'UGR', 61.3124504, 63.3364787);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Аша', 'ASH', 54.9907105, 57.2783704);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Бакал', 'BAK', 54.9406759, 58.8051085);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Верхнеуральск', 'VER', 53.8760587, 59.2169071);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Верхний Уфалей', 'VFU', 56.0487252, 60.231963);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Еманжелинск', 'EME', 54.7554084, 61.3243985);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Златоуст', 'ZLT', 55.1715695, 59.6726264);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Карабаш', 'KRB', 55.4852076, 60.2358959);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Карталы', 'KAR', 53.0536101, 60.647712);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Касли', 'KSL', 55.8868045, 60.7422529);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Катав-Ивановск', 'KAI', 54.7520187, 58.1983706);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Копейск', 'KOP', 55.1167545, 61.6180809);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Коркино', 'KOR', 54.8903023, 61.4034541);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Куса', 'KUS', 55.3385156, 59.4386474);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кыштым', 'KYS', 55.7060048, 60.5563271);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Магнитогорск', 'MGN', 53.4071891, 58.9791432);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Миасс', 'MI', 55.0455774, 60.1077757);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Миньяр', 'MIN', 55.0709601, 57.5484435);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нязепетровск', 'NZP', 56.0537199, 59.6096791);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Озерск', 'OZ', 55.7631922, 60.7076337);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Пласт', 'PLS', 54.3691832, 60.8152305);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сатка', 'SAT', 55.0404497, 59.0288153);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Сим', 'SIM', 54.9906584, 57.6899045);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Снежинск', 'SNE', 56.085232, 60.7324989);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Трехгорный', 'TRE', 54.8178174, 58.4465039);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Троицк', 'TRO', 54.0844132, 61.5585503);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Усть-Катав', 'UST', 54.9261323, 58.1528067);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Чебаркуль', 'CHE', 54.9819329, 60.3773305);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Челябинск', 'CEK', 55.1603659, 61.4007858);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Южноуральск', 'YUZ', 54.4490124, 61.2581869);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Юрюзань', 'YUR', 54.8546372, 58.4227116);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Аргун', 'ARG', 43.2918071, 45.8724383);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Грозный', 'GRV', 43.3179243, 45.6981102);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Гудермес', 'GCM', 43.3519164, 46.1036052);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Урус-Мартан', 'URM', 43.1276072, 45.5406838);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Шали', 'SHL', 43.148776, 45.9009577);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Алатырь', 'ALA', 54.8398179, 46.5721423);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Канаш', 'KAN', 55.5069543, 47.4917734);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Козловка', 'KZV', 55.8406526, 48.2579372);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мариинский Посад', 'MRP', 56.111968, 47.7142676);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Новочебоксарск', 'CNK', 56.109486, 47.4791429);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Цивильск', 'TSV', 55.8650132, 47.472967);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Чебоксары', 'CSY', 56.1439378, 47.2488718);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Шумерля', 'SHM', 55.4961795, 46.4183534);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ядрин', 'YAD', 55.9406826, 46.2020765);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Анадырь', 'DYR', 64.7314347, 177.5015752);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Билибино', 'BIK', 68.0585533, 166.4388451);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Певек', 'PWE', 69.7018051, 170.2999194);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Алдан', 'ADH', 58.6094885, 125.3816689);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Верхоянск', 'VHY', 67.5500865, 133.3907829);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Вилюйск', 'VYU', 63.7517314, 121.6272754);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ленск', 'LNX', 60.7276036, 114.9549103);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мирный', 'MJZ', 62.5362511, 113.9668146);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нерюнгри', 'NER', 56.6600322, 124.72031);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Нюрба', 'NYR', 63.2828775, 118.324325);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Олекминск', 'OLE', 60.3758203, 120.406013);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Покровск', 'PKV', 61.4843538, 129.1482195);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Среднеколымск', 'SEK', 67.4581664, 153.7069511);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Томмот', 'TOF', 58.9586939, 126.2875375);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Удачный', 'PYJ', 66.4072367, 112.3061653);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Якутск', 'YKS', 62.0280273, 129.7325717);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Губкинский', 'GUB', 64.4456575, 76.4714559);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Лабытнанги', 'LAV', 66.6592376, 66.3882628);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Муравленко', 'NYR', 63.794188, 74.494913);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Надым', 'NYM', 65.5377514, 72.5182746);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Новый Уренгой', 'NUX', 66.0840036, 76.6810032);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ноябрьск', 'NOY', 63.201846, 75.4509665);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Салехард', 'SLY', 66.5493568, 66.6083994);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тарко-Сале', 'TYM', 64.9117649, 77.7610204);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Гаврилов-Ям', 'GVR', 57.3091552, 39.8545157);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Данилов', 'DAN', 58.1859542, 40.1796765);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Любим', 'LYU', 58.3619868, 40.6869581);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мышкин', 'MYA', 57.7881664, 38.4542816);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Переславль-Залесский', 'PER', 56.7360435, 38.8543064);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Пошехонье', 'POS', 58.506328, 39.1210034);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ростов', 'ROS', 57.2050177, 39.4378357);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Рыбинск', 'RYB', 58.0483802, 38.858338);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Тутаев', 'TUT', 57.8674237, 39.5368234);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Углич', 'UGL', 57.5223866, 38.3019793);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ярославль', 'IAR', 57.6216145, 39.897878);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кудрово', 'KUD', 59.906944, 30.505556);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Мурино', 'MUR', 60.04796, 30.45204);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Курчалой', 'KUR', 43.2021, 46.09);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Кукмор', 'KUK', 56.1855, 50.8944);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Белоозёрский', 'BEO', 55.459619, 38.43892);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Ачхой-мартан', 'ACM', 43.18997, 45.28373);
# INSERT INTO router.City(name, code, latitude, longitude) VALUES('Колтуши', 'KOL', 59.92969, 30.64465);

# %% [markdown]
# ## Команды

# %% [markdown]
# __1. Создание и заполнение БД__: `psql -U postgres -q -b -f create_db.sql`\
# __2. Проверка кодировки сервера__: `show server_encoding;`

# %% [markdown]
# __3. DB checks__
# ```SQL
# select *
# from router.city
# where lower(name) like 'мо%';
#
# select name, count(name) as dup_cnt
# from router.city c
# group by name
# having count(name) > 1;
#
# select * from router.city where name = 'Ялта';
#
# select count(*), (select count(*) from router.city)
# from (
# 	select *
# 	from router.city
# 	group by id, name, latitude, longitude
# ) as dedup;
# ```
