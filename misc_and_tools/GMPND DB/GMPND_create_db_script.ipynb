# %% [markdown]
# # Скрипт для создания и заполнения БД

# %% [markdown]
# ## Парсинг JSON и формирование sql скрипта

# %%
import pandas as pd
import numpy as np

# %%
import json

# %% [markdown]
# ### Скрип создания базы и переменные БД

# %%
DATABASE_OWNER = 'postgres' # Юзер БД (админ сервера)
ENCODING = 'UTF8' # Выбранная кодировка должна соответствовать кодировке сервера (на всякий случай)
LOCALE = 'ru_RU'

DATABASE_NAME = 'glemapanida'
SCHEMA_NAME = 'router'
TABLE_NAME = 'City'

# %%
create_db_q = f"""CREATE DATABASE {DATABASE_NAME} WITH
OWNER "{DATABASE_OWNER}"
ENCODING '{ENCODING}'
LC_COLLATE = '{LOCALE}.{ENCODING}'
LC_CTYPE = '{LOCALE}.{ENCODING}'
TEMPLATE template0;

\c {DATABASE_NAME};
set client_encoding TO '{ENCODING}';
"""

create_schema_table_q = f"""
CREATE SCHEMA {SCHEMA_NAME}
    CREATE TABLE {TABLE_NAME} (
        id SERIAL PRIMARY KEY,
        name VARCHAR(25) NOT NULL,
        code VARCHAR(5) NOT NULL,
        code_yandex VARCHAR(10) NOT NULL,
        latitude NUMERIC(10, 7) NOT NULL,
        longitude NUMERIC(10, 7) NOT NULL
    );

CREATE INDEX name_code_idx ON {SCHEMA_NAME}.{TABLE_NAME} ((lower(name)), code);
CREATE INDEX name_code_ya_idx ON {SCHEMA_NAME}.{TABLE_NAME} ((lower(name)), code_yandex);
"""

# %% [markdown]
# ### Города, координаты, международные коды

# %%
city_data = pd.read_excel('data/cities.xlsx').drop_duplicates().reset_index(drop=True)
city_data['name'] = city_data['name'].str.strip()
city_data['code'] = city_data['code'].str.strip()

# %%
city_data.head()
# Out:
#             name   latitude  longitude code
# 0       Адыгейск  44.878372  39.190172  ADY
# 1         Майкоп  44.609827  40.100653  MAY
# 2  Горно-Алтайск  51.958268  85.960296  GOA
# 3         Алейск  52.492091  82.779415  ALY
# 4        Барнаул  53.348115  83.779836  BAX

# %%
city_data.isna().any()
# Out:
# name         False
# latitude     False
# longitude    False
# code         False
# dtype: bool

# %%
city_data.dtypes
# Out:
# name          object
# latitude     float64
# longitude    float64
# code          object
# dtype: object

# %%
city_data.shape
# Out:
# (1119, 4)

# %%
city_data = city_data.drop_duplicates(subset=['name'], keep=False).reset_index(drop=True)

# %%
city_data.shape
# Out:
# (1078, 4)

# %% [markdown]
# Потери при удалении одноимённых городов: 41 наименование

# %% [markdown]
# ### Коды яндекса

# %%
with open('data/allYandex.json', 'r', encoding=f'{ENCODING}') as f:
    yac = json.load(f)

# %%
ya_city_code = {
    'name': [],
    'code_yandex': []
}

for country in yac['countries']:
    if country['title'] == 'Россия':
        for region in country['regions']:
            for settlement in region['settlements']:
                if settlement['title'] in city_data.name.unique().tolist():
                    if settlement['title'] in ya_city_code['name']:
                        idx = ya_city_code['name'].index(settlement['title'])
                        del ya_city_code['name'][idx]
                        del ya_city_code['code_yandex'][idx]
                    else:
                        ya_city_code['name'].append(settlement['title'])
                        ya_city_code['code_yandex'].append(settlement['codes']['yandex_code'])

# %%
ya_city_code_df = pd.DataFrame(ya_city_code)

# %%
ya_city_code_df.name.isin(city_data.name.unique().tolist()).sum()
# Out:
# 966

# %% [markdown]
# Потери при удалении... какой-то хуйни: 112 наименований

# %%
city_data[~city_data.name.isin(ya_city_code_df.name.unique().tolist())].name.unique()
# Out:
# array(['Свободный', 'Знаменск', 'Строитель', 'Сельцо', 'Киржач',
#        'Костерево', 'Муром', 'Покров', 'Новохоперск', 'Россошь',
#        'Иваново', 'Комсомольск', 'Родники', 'Шуя', 'Карабулак', 'Саянск',
#        'Черемхово', 'Майский', 'Чегем', 'Гусев', 'Пионерский',
#        'Светлогорск', 'Светлый', 'Белоусово', 'Ермолино', 'Жуков',
#        'Вилючинск', 'Елизово', 'Сосновка', 'Буй', 'Мантурово', 'Нерехта',
#        'Горячий Ключ', 'Артемовск', 'Зеленогорск', 'Сосновоборск',
#        'Щучье', 'Дмитриев', 'Отрадное', 'Пикалево', 'Сосновый Бор',
#        'Козьмодемьянск', 'Ардатов', 'Дубна', 'Ивантеевка', 'Истра',
#        'Королев', 'Куровское', 'Ликино-Дулево', 'Озеры', 'Пущино',
#        'Щелково', 'Полярный', 'Бор', 'Горбатов', 'Городец', 'Заволжье',
#        'Лысково', 'Павлово', 'Первомайск', 'Семенов', 'Боровичи',
#        'Купино', 'Дмитровск', 'Городище', 'Каменка', 'Верещагино',
#        'Горнозаводск', 'Гремячинск', 'Усолье', 'Артем', 'Находка',
#        'Остров', 'Зверево', 'Рыбное', 'Северо-Курильск', 'Артемовский',
#        'Лесной', 'Талица', 'Дигора', 'Ельня', 'Починок', 'Рудня',
#        'Ярцево', 'Буденновск', 'Уварово', 'Вышний Волочек',
#        'Красный Холм', 'Кувшиново', 'Нелидово', 'Кедровый', 'Северск',
#        'Белев', 'Венев', 'Ясногорск', 'Ак-Довурак', 'Чадан', 'Шагонар',
#        'Белоярский', 'Советский', 'Сургут', 'Карабаш', 'Троицк', 'Канаш',
#        'Билибино', 'Верхоянск', 'Ленск', 'Олекминск', 'Удачный',
#        'Курчалой', 'Ачхой-мартан', 'Колтуши'], dtype=object)

# %%
city_data = pd.merge(
    city_data,
    ya_city_code_df,
    how='inner',
    on='name',
    validate='1:1'
)

city_data.head()
# Out:
#             name   latitude  longitude code code_yandex
# 0       Адыгейск  44.878372  39.190172  ADY      c11005
# 1         Майкоп  44.609827  40.100653  MAY       c1093
# 2  Горно-Алтайск  51.958268  85.960296  GOA      c11319
# 3         Алейск  52.492091  82.779415  ALY      c11234
# 4        Барнаул  53.348115  83.779836  BAX        c197

# %% [markdown]
# ### Скрипт вставки данных

# %%
def extract_info(city):
    city_name = city['name']
    city_lat = city.latitude
    city_lon = city.longitude
    city_code = city.code
    city_code_yandex = city.code_yandex
    
    return f"""INSERT INTO {SCHEMA_NAME}.{TABLE_NAME}(name, code, code_yandex, latitude, longitude) VALUES('{city_name}', '{city_code}', '{city_code_yandex}', {city_lat}, {city_lon});
"""

# %%
insert_into_table_q = f"""
""" + ''.join(city_data.apply(extract_info, axis=1).values.tolist())

# %%
query_str = create_db_q + create_schema_table_q + insert_into_table_q

# %%
with open('create_db.sql', 'w', encoding=f'{ENCODING}') as f:
    f.write(query_str)

# %%
with open('create_db.sql', 'r', encoding=f'{ENCODING}') as f:
    print(f.read())
# Out:
# CREATE DATABASE glemapanida WITH
# OWNER "postgres"
# ENCODING 'UTF8'
# LC_COLLATE = 'ru_RU.UTF8'
# LC_CTYPE = 'ru_RU.UTF8'
# TEMPLATE template0;
#
# \c glemapanida;
# set client_encoding TO 'UTF8';
#
# CREATE SCHEMA router
#     CREATE TABLE City (
#         id SERIAL PRIMARY KEY,
#         name TEXT NOT NULL,
#         code TEXT NOT NULL,
#         code_yandex TEXT NOT NULL,
#         latitude NUMERIC(10, 7) NOT NULL,
#         longitude NUMERIC(10, 7) NOT NULL
#     );
#
# CREATE INDEX name_code_idx ON router.City ((lower(name)), code);
# CREATE INDEX name_code_ya_idx ON router.City ((lower(name)), code_yandex);
#
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Адыгейск', 'ADY', 'c11005', 44.8783715, 39.190172);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Майкоп', 'MAY', 'c1093', 44.6098268, 40.1006527);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Горно-Алтайск', 'GOA', 'c11319', 51.9582681, 85.9602957);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Алейск', 'ALY', 'c11234', 52.4920914, 82.7794145);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Барнаул', 'BAX', 'c197', 53.3481145, 83.7798362);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Белокуриха', 'BEY', 'c11236', 51.9960534, 84.9840343);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Бийск', 'BIK', 'c975', 52.5393683, 85.2138852);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Горняк', 'GOR', 'c11239', 50.9979032, 81.4643059);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Заринск', 'ZAR', 'c11240', 53.7063495, 84.9314703);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Змеиногорск', 'ZME', 'c11241', 51.1580235, 82.1872476);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Камень-на-Оби', 'KOB', 'c11242', 53.7915454, 81.3545173);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Новоалтайск', 'NAL', 'c11246', 53.4120811, 83.9311249);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Рубцовск', 'RUB', 'c11251', 51.5013075, 81.2077729);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Славгород', 'SLA', 'c11252', 52.9993053, 78.6459674);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Яровое', 'YAR', 'c20080', 52.9251728, 78.5729898);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Завитинск', 'ZAV', 'c11378', 50.1064678, 129.4392897);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Зея', 'ZEA', 'c11379', 53.7339151, 127.2658079);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Райчихинск', 'RAJ', 'c11385', 49.7941882, 129.4112149);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сковородино', 'SKO', 'c11389', 53.9871004, 123.943729);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тында', 'TYA', 'c11391', 55.1546401, 124.7468634);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Циолковский', 'TSJ', 'c39511', 51.7624346, 128.121972);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Шимановск', 'SHI', 'c11392', 52.0052856, 127.7006559);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Архангельск', 'ARH', 'c20', 64.5392985, 40.5170083);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Вельск', 'VEL', 'c10843', 61.0660057, 42.1032858);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Каргополь', 'KAR', 'c10844', 61.5008762, 38.9636415);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Коряжма', 'KOY', 'c10845', 61.2885993, 47.1002315);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Котлас', 'KOS', 'c10846', 61.2529842, 46.6331915);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Мезень', 'MEZ', 'c20114', 65.8398386, 44.2531865);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Новодвинск', 'NVD', 'c20117', 64.4136023, 40.8208003);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Няндома', 'NYA', 'c20602', 61.6653735, 40.2061699);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Онега', 'ONE', 'c10847', 63.9163966, 38.0805749);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Северодвинск', 'SEV', 'c10849', 64.56253, 39.8182715);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сольвычегодск', 'SOL', 'c21852', 61.3318091, 46.920351);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Шенкурск', 'SHE', 'c10851', 62.1057423, 42.89959);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Астрахань', 'ASF', 'c37', 46.3655808, 48.0559979);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ахтубинск', 'AHT', 'c20167', 48.2753078, 46.1906741);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Камызяк', 'KAM', 'c20168', 46.1105429, 48.0732724);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нариманов', 'NRM', 'c20169', 46.6916597, 47.8501624);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Харабали', 'KHA', 'c20170', 47.4089187, 47.2524467);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Агидель', 'AGI', 'c21770', 55.89976, 53.9221149);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Баймак', 'BYM', 'c20673', 52.5912632, 58.3111995);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Белебей', 'BEL', 'c20714', 54.1033832, 54.1111878);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Белорецк', 'BEC', 'c20259', 53.9675927, 58.4099562);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Бирск', 'BIR', 'c20689', 55.4157107, 55.5582335);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Давлеканово', 'DAV', 'c20639', 54.2227617, 55.0313419);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Дюртюли', 'DUR', 'c20668', 55.4848047, 54.8524875);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ишимбай', 'ISH', 'c20718', 53.4546314, 56.043874);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кумертау', 'KUM', 'c11113', 52.7565537, 55.7969915);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Межгорье', 'MEJ', 'c24525', 54.239683, 57.96146);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Мелеуз', 'MEE', 'c20715', 52.9590637, 55.9283483);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нефтекамск', 'NEF', 'c11114', 56.0883075, 54.2483391);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Октябрьский', 'OKT', 'c42391', 54.4815344, 53.4656611);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Салават', 'SAL', 'c11115', 53.3616311, 55.9245559);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сибай', 'SIB', 'c20716', 52.7205811, 58.6663303);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Стерлитамак', 'STK', 'c11116', 53.6302498, 55.9315707);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Туймазы', 'TUI', 'c20717', 54.5999889, 53.6949081);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Уфа', 'UFA', 'c172', 54.734853, 55.9578647);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Учалы', 'UCH', 'c20680', 54.3066965, 59.4126559);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Янаул', 'YAN', 'c20656', 56.2650336, 54.9298314);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Алексеевка', 'ALX', 'c21876', 50.6299932, 38.6881776);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Белгород', 'BLP', 'c4', 50.5977351, 36.5858236);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Бирюч', 'BIR', 'c21953', 50.6483899, 38.4006203);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Валуйки', 'VAL', 'c20193', 50.2112799, 38.0998765);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Грайворон', 'GRV', 'c20194', 50.4862699, 35.6662957);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Губкин', 'GUB', 'c10646', 51.2836362, 37.5347608);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Короча', 'KRC', 'c20195', 50.8130123, 37.1896543);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Новый Оскол', 'NOS', 'c10647', 50.7635162, 37.8774026);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Старый Оскол', 'STO', 'c10649', 51.2965991, 37.8349849);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Шебекино', 'SHE', 'c20196', 50.4005506, 36.8877988);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Брянск', 'BRY', 'c191', 53.2420071, 34.3652716);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Дятьково', 'DYA', 'c10651', 53.5958283, 34.355092);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Жуковка', 'ZHK', 'c33793', 53.5341219, 33.7302166);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Злынка', 'ZLY', 'c20184', 52.4265906, 31.7360386);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Карачев', 'KRC', 'c10655', 53.1297194, 34.9887859);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Клинцы', 'KLI', 'c10653', 52.7529052, 32.2339161);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Мглин', 'MGL', 'c20185', 53.0600644, 32.8467217);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Новозыбков', 'NVS', 'c10654', 52.5371426, 31.9356826);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Почеп', 'POC', 'c20186', 52.9154724, 33.4744608);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Севск', 'SEK', 'c20187', 52.1484215, 34.4918198);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Стародуб', 'STA', 'c20188', 52.5851881, 32.7603628);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сураж', 'SUR', 'c20189', 53.0171239, 32.3938351);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Трубчевск', 'TRU', 'c20190', 52.5791314, 33.7660013);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Унеча', 'UNE', 'c20191', 52.8460665, 32.6757071);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Бабушкин', 'BAB', 'c21816', 51.7113066, 105.8673633);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Гусиноозерск', 'GUS', 'c11326', 51.2865751, 106.5230732);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Закаменск', 'ZAK', 'c20081', 50.3726774, 103.2867452);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кяхта', 'KYA', 'c20082', 50.3466291, 106.4534938);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Северобайкальск', 'SEB', 'c11327', 55.6357165, 109.3362606);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Улан-Удэ', 'UUD', 'c198', 51.8334378, 107.5841511);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Александров', 'ALA', 'c10656', 56.3919652, 38.711035);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Владимир', 'VLA', 'c192', 56.1281561, 40.4082995);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Вязники', 'VZN', 'c10659', 56.2976528, 42.2687311);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Гороховец', 'GRH', 'c10660', 56.2021059, 42.692517);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Гусь-Хрустальный', 'GKH', 'c10661', 55.6198065, 40.6578769);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Камешково', 'KAV', 'c10662', 56.3488712, 40.9955682);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Карабаново', 'KAR', 'c28798', 56.3133447, 38.7034267);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ковров', 'KVR', 'c10664', 56.3553895, 41.3169568);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кольчугино', 'KOG', 'c10665', 56.3327616, 39.391201);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Курлово', 'KUL', 'c24450', 55.4525994, 40.6124362);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Лакинск', 'LKN', 'c22340', 56.0180614, 39.9564706);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Меленки', 'MEL', 'c85059', 55.3387017, 41.634124);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Петушки', 'PET', 'c10669', 55.9297657, 39.4507913);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Собинка', 'SOB', 'c10670', 55.993798, 40.0180034);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Струнино', 'STR', 'c22342', 56.3750001, 38.583938);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Судогда', 'SUD', 'c20629', 55.949897, 40.8563392);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Суздаль', 'SUZ', 'c10671', 56.4273814, 40.4525581);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Юрьев-Польский', 'YUR', 'c20757', 56.4938067, 39.6679311);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Волгоград', 'VOG', 'c38', 48.7072005, 44.5170207);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Волжский', 'VLS', 'c10951', 48.7978483, 44.7462417);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Дубовка', 'DUB', 'c10954', 49.0555342, 44.8270813);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Жирновск', 'ZHR', 'c10956', 50.9767561, 44.7857694);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Калач-на-Дону', 'KND', 'c10958', 48.6887569, 43.5306866);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Камышин', 'KAM', 'c10959', 50.0651261, 45.3843816);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Котельниково', 'KOT', 'c10961', 47.6310808, 43.1331198);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Котово', 'KOO', 'c52605', 50.3205433, 44.8031864);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ленинск', 'LEN', 'c10964', 48.6936234, 45.1992835);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Михайловка', 'MIK', 'c85213', 50.0708749, 43.2400847);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Николаевск', 'NIK', 'c10967', 50.0166952, 45.4733204);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Новоаннинский', 'NVA', 'c10968', 50.5296873, 42.6666038);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Палласовка', 'PAL', 'c10972', 50.0501422, 46.8803355);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Петров Вал', 'PTB', 'c10973', 50.1380355, 45.2091455);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Серафимович', 'SER', 'c10977', 49.566286, 42.7360013);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Суровикино', 'SUO', 'c10980', 48.6189756, 42.8541308);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Урюпинск', 'URP', 'c10981', 50.7904767, 42.0288589);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Фролово', 'FRO', 'c10982', 49.7647809, 43.6648936);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Бабаево', 'BAB', 'c20118', 59.389309, 35.9378318);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Белозерск', 'BLZ', 'c20119', 60.0307914, 37.7891123);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Великий Устюг', 'VUS', 'c10854', 60.7603243, 46.3053893);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Вологда', 'VLG', 'c21', 59.2484186, 39.8356461);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Вытегра', 'VYI', 'c20120', 61.0064157, 36.4495835);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Грязовец', 'GZT', 'c20121', 58.8757657, 40.248477);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кадников', 'KAD', 'c22423', 59.5037947, 40.3440473);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кириллов', 'KRR', 'c20122', 59.8590353, 38.3749854);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Красавино', 'KRV', 'c22431', 60.9613991, 46.481465);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сокол', 'SOK', 'c20124', 59.4759156, 40.1114414);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тотьма', 'TOT', 'c10855', 59.9735051, 42.7589701);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Устюжна', 'USH', 'c10856', 58.8383671, 36.4425046);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Харовск', 'KHA', 'c20125', 59.9477728, 40.2000794);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Череповец', 'CHP', 'c968', 59.1269214, 37.9092243);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Бобров', 'BOB', 'c10673', 51.0902048, 40.0320014);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Богучар', 'BOG', 'c10674', 49.9352997, 40.5592467);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Борисоглебск', 'BOR', 'c10675', 51.3654619, 42.100947);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Бутурлиновка', 'BUT', 'c10676', 50.8313227, 40.5977541);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Воронеж', 'VOZ', 'c193', 51.6592378, 39.1968284);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Калач', 'KAL', 'c10677', 50.4241213, 41.0162858);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Лиски', 'LIS', 'c10678', 50.9944734, 39.518302);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нововоронеж', 'NVJ', 'c20268', 51.3092463, 39.2162865);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Острогожск', 'OSK', 'c10679', 50.8678083, 39.0406398);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Павловск', 'PAV', 'c10680', 50.4533684, 40.1369087);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Поворино', 'POV', 'c20694', 51.1953446, 42.2472432);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Семилуки', 'SMI', 'c10682', 51.6951846, 39.0189797);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Эртиль', 'ERT', 'c10683', 51.831024, 40.8074054);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Буйнакск', 'BUI', 'c11006', 42.8213799, 47.1164452);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Дагестанские Огни', 'DGO', 'c21732', 42.1151021, 48.1939983);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Дербент', 'DER', 'c11007', 42.058935, 48.2908653);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Избербаш', 'IZB', 'c21521', 42.565098, 47.871002);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Каспийск', 'KAS', 'c11008', 42.8916599, 47.6366674);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кизилюрт', 'KZY', 'c21519', 43.2039094, 46.8729311);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кизляр', 'KIZ', 'c11009', 43.8483915, 46.7232828);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Махачкала', 'MCX', 'c28', 42.9848572, 47.5046303);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Хасавюрт', 'HSR', 'c11011', 43.2505191, 46.5852276);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Южно-Сухокумск', 'YUZ', 'c21834', 44.6600972, 45.6499304);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Биробиджан', 'BJO', 'c11393', 48.7945975, 132.9217594);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Облучье', 'OBU', 'c11394', 49.0188344, 131.0539984);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Балей', 'BAJ', 'c22961', 51.5822063, 116.6380088);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Борзя', 'BAZ', 'c11355', 50.3875437, 116.5235682);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Краснокаменск', 'KAM', 'c11358', 50.092858, 118.0323407);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Могоча', 'MGO', 'c11360', 53.7362465, 119.7661232);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нерчинск', 'NER', 'c11361', 51.9595512, 116.5854018);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Петровск-Забайкальский', 'PBZ', 'c11364', 51.2748381, 108.8467139);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сретенск', 'SRT', 'c11366', 52.2462356, 117.7116971);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Хилок', 'HIL', 'c11368', 51.3635236, 110.458989);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Чита', 'HTA', 'c68', 52.0340128, 113.4994884);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Шилка', 'SHC', 'c11371', 51.8495302, 116.033575);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Вичуга', 'VCH', 'c10688', 57.2044545, 41.9131192);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Гаврилов Посад', 'GPO', 'c20597', 56.5585967, 40.1228288);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Заволжск', 'ZAV', 'c22384', 57.4916546, 42.1374455);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кинешма', 'KNE', 'c10689', 57.4425441, 42.1690039);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кохма', 'KHM', 'c10690', 56.9325151, 41.0933071);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Наволоки', 'NAV', 'c24448', 57.4678426, 41.9607371);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Плес', 'PLE', 'c22389', 57.4605304, 41.512301);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Приволжск', 'PVI', 'c22390', 57.3807249, 41.2809239);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Пучеж', 'PUC', 'c20613', 56.982075, 43.1683878);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тейково', 'TEI', 'c20229', 56.8542712, 40.5355289);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Фурманов', 'FUR', 'c20682', 57.2538043, 41.1053808);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Южа', 'YUZ', 'c20648', 56.5926458, 42.0457159);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Юрьевец', 'YUR', 'c10692', 57.3178701, 43.1110553);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Магас', 'MAG', 'c20181', 43.1686967, 44.8130849);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Малгобек', 'MAL', 'c20179', 43.5097009, 44.5901517);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Назрань', 'NAZ', 'c1092', 43.2257977, 44.764685);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Алзамай', 'ALZ', 'c24497', 55.5550493, 98.6644106);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ангарск', 'ANG', 'c11256', 52.5448102, 103.8885385);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Байкальск', 'BAI', 'c11257', 51.5231282, 104.1485752);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Бирюсинск', 'BIR', 'c11259', 55.9608611, 97.8203624);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Бодайбо', 'BOD', 'c11260', 57.8468822, 114.1867148);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Братск', 'BRA', 'c976', 56.1513951, 101.6339892);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Вихоревка', 'VIH', 'c11262', 56.1207708, 101.170332);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Железногорск-Илимский', 'ZHE', 'c11264', 56.5847382, 104.1141747);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Зима', 'ZIM', 'c11265', 53.9206865, 102.0492066);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Иркутск', 'IRT', 'c63', 52.2863513, 104.280655);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Киренск', 'KIR', 'c11267', 57.7757126, 108.1107766);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нижнеудинск', 'NIZ', 'c11268', 54.8969105, 99.0313481);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Свирск', 'SVI', 'c22945', 53.0842576, 103.3364192);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Слюдянка', 'SLY', 'c20096', 51.6562679, 103.7186877);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тайшет', 'TAI', 'c11270', 55.9405397, 98.0030649);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тулун', 'TUL', 'c11271', 54.5571409, 100.5779402);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Усолье-Сибирское', 'USL', 'c11272', 52.7567192, 103.6387694);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Усть-Илимск', 'UIS', 'c11273', 57.9431325, 102.7414683);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Усть-Кут', 'USK', 'c20097', 56.7928049, 105.7756883);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Шелехов', 'SHE', 'c11275', 52.2102462, 104.0973531);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Баксан', 'BAK', 'c20171', 43.6820621, 43.5345627);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нальчик', 'NAL', 'c30', 43.4846312, 43.6070316);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нарткала', 'NAN', 'c20173', 43.5577208, 43.8576411);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Прохладный', 'PRO', 'c20174', 43.7589521, 44.0101936);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Терек', 'TER', 'c20175', 43.4838439, 44.1402524);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тырныауз', 'TYA', 'c20176', 43.3981939, 42.9215127);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Багратионовск', 'BAG', 'c20135', 54.3866976, 20.6418545);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Балтийск', 'BAL', 'c10858', 54.6514128, 19.9141911);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Гвардейск', 'GVA', 'c20136', 54.6588981, 21.0500584);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Зеленоградск', 'ZEL', 'c20139', 54.9600226, 20.4753274);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Калининград', 'KGD', 'c22', 54.7073218, 20.5072458);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ладушкин', 'LAD', 'c20580', 54.5693538, 20.1691909);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Мамоново', 'MAM', 'c61605', 54.4645591, 19.9454114);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Неман', 'NEM', 'c20141', 55.0315543, 22.0323961);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нестеров', 'NES', 'c20142', 54.6314454, 22.5713658);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Полесск', 'POL', 'c20145', 54.8626321, 21.0998148);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Правдинск', 'PRA', 'c20146', 54.4430604, 21.0083638);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Славск', 'SLA', 'c20148', 55.0451054, 21.6742294);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Черняховск', 'CHE', 'c20149', 54.6243928, 21.7969179);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Городовиковск', 'GOR', 'c20177', 46.0875351, 41.9354039);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Лагань', 'LAG', 'c20178', 45.3929617, 47.3432943);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Элиста', 'ELS', 'c1094', 46.3082947, 44.2701417);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Балабаново', 'BAL', 'c20197', 55.1773652, 36.6567255);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Боровск', 'BOR', 'c10698', 55.2130965, 36.4927446);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Жиздра', 'ZHI', 'c20198', 53.7522384, 34.7386719);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Калуга', 'KLU', 'c6', 54.5060439, 36.2515933);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Козельск', 'KOZ', 'c10695', 54.0348417, 35.7807136);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кондрово', 'KND', 'c10696', 54.796051, 35.9276099);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кременки', 'KRE', 'c24368', 54.8863306, 37.116878);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Людиново', 'LUD', 'c20201', 53.8701406, 34.4385498);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Малоярославец', 'MAL', 'c10697', 55.0176756, 36.4632122);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Медынь', 'MED', 'c20202', 54.9690755, 35.887313);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Мещовск', 'MES', 'c20203', 54.3191127, 35.2816065);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Мосальск', 'MOS', 'c20204', 54.4825589, 34.987206);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Обнинск', 'OBN', 'c967', 55.0943892, 36.6121785);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сосенский', 'SOS', 'c20205', 54.056525, 35.9621458);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Спас-Деменск', 'SPD', 'c20206', 54.4099201, 34.0190263);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сухиничи', 'SUK', 'c20207', 54.0973787, 35.3443077);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Таруса', 'TAR', 'c20208', 54.7236791, 37.1670866);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Юхнов', 'YUK', 'c20209', 54.7445873, 35.2424857);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Петропавловск-Камчатский', 'PKC', 'c78', 53.0370213, 158.6559142);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Карачаевск', 'KAR', 'c11017', 43.773197, 41.9143726);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Теберда', 'TEB', 'c11018', 43.4438408, 41.7414924);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Усть-Джегута', 'USD', 'c11019', 44.083852, 41.971128);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Черкесск', 'CHK', 'c1104', 44.2268637, 42.0467829);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Беломорск', 'BEM', 'c10938', 64.5378468, 34.7799717);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кемь', 'KEM', 'c20126', 64.9543657, 34.5948547);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кондопога', 'KON', 'c10934', 62.2059866, 34.2681778);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Костомукша', 'KOS', 'c10935', 64.5889946, 30.6015567);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Лахденпохья', 'LAH', 'c20127', 61.5189466, 30.199592);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Медвежьегорск', 'MED', 'c20128', 62.9127678, 34.4567614);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Олонец', 'OLO', 'c20129', 60.9793604, 32.9726031);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Петрозаводск', 'PET', 'c18', 61.78909, 34.3596263);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Питкяранта', 'PIT', 'c20130', 61.5756886, 31.4641309);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Пудож', 'PUD', 'c20131', 61.8059147, 36.5330088);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сегежа', 'SEG', 'c10936', 63.7437211, 34.3126755);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сортавала', 'SOR', 'c10937', 61.7032216, 30.6917021);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Суоярви', 'SUO', 'c20132', 62.0787769, 32.3499029);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Анжеро-Судженск', 'ANZ', 'c11276', 56.0787179, 86.0202207);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Белово', 'BEL', 'c11277', 54.4221442, 86.3036438);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Калтан', 'KAL', 'c21703', 53.5210461, 87.2772143);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кемерово', 'KEM', 'c64', 55.3909721, 86.0467864);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Киселевск', 'KIS', 'c11283', 54.0060382, 86.6367387);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ленинск-Кузнецкий', 'LEN', 'c11285', 54.6674092, 86.1796724);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Мариинск', 'MAR', 'c11286', 56.2127836, 87.7454392);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Междуреченск', 'MEZ', 'c11287', 53.6865695, 88.0703888);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Мыски', 'MYS', 'c11288', 53.7125516, 87.8056657);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Новокузнецк', 'NOV', 'c237', 53.7942757, 87.2144046);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Осинники', 'OSI', 'c11290', 53.5987397, 87.3369948);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Полысаево', 'POL', 'c11292', 54.6053968, 86.2808803);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Прокопьевск', 'PRO', 'c11291', 53.8604562, 86.7183428);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Салаир', 'SAL', 'c11294', 54.2351588, 85.8029215);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тайга', 'TAI', 'c20645', 56.0622767, 85.6207907);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Таштагол', 'TAS', 'c11295', 52.7594505, 87.8477272);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Топки', 'TOP', 'c11297', 55.2766036, 85.6153223);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Юрга', 'YUR', 'c11299', 55.7202689, 84.8885516);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Белая Холуница', 'BEL', 'c20019', 58.8415212, 50.8461002);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Вятские Поляны', 'VYA', 'c20020', 56.2286058, 51.0614666);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Зуевка', 'ZUE', 'c20021', 58.4031674, 51.1330787);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кирово-Чепецк', 'KCH', 'c11071', 58.5559921, 50.0317608);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кирс', 'KRS', 'c20022', 59.3400586, 52.2415895);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Котельнич', 'KOT', 'c20023', 58.3035238, 48.3474288);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Луза', 'LUZ', 'c20024', 60.6290781, 47.2612069);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Малмыж', 'MAL', 'c20025', 56.5243722, 50.6782757);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Мураши', 'MUR', 'c20026', 59.3956347, 48.9637651);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нолинск', 'NOL', 'c20027', 57.5596946, 49.9357867);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Омутнинск', 'OMU', 'c20028', 58.6697684, 52.1893554);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Орлов', 'ORL', 'c20029', 58.5389402, 48.8929268);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Слободской', 'SLO', 'c11073', 58.7311934, 50.1670091);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Уржум', 'URJ', 'c20030', 57.1097612, 50.0056278);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Яранск', 'YAR', 'c11075', 57.304195, 47.8479185);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Воркута', 'VOR', 'c10940', 67.4973484, 64.0611045);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Вуктыл', 'VUK', 'c20133', 63.8615209, 57.3165207);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Емва', 'EMB', 'c20134', 62.5965314, 50.8731889);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Инта', 'INT', 'c10941', 66.0368196, 60.1154612);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Микунь', 'MIK', 'c21695', 62.3580188, 50.0719738);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Печора', 'PEC', 'c10942', 65.1485717, 57.22388);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сосногорск', 'SOS', 'c10943', 63.5990137, 53.8762792);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сыктывкар', 'SYK', 'c19', 61.668789, 50.8356491);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Усинск', 'USI', 'c10944', 65.9941116, 57.5570054);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ухта', 'UKH', 'c10945', 63.5564779, 53.7014202);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Волгореченск', 'VOL', 'c10701', 57.4423712, 41.1593076);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Галич', 'GAL', 'c10703', 58.3826861, 42.3654563);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кологрив', 'KOL', 'c20215', 58.826988, 44.3185323);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кострома', 'KOS', 'c7', 57.8029445, 40.9907282);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Макарьев', 'MAK', 'c20216', 57.8808916, 43.8014428);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нея', 'NEY', 'c20621', 58.2944499, 43.8780965);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Солигалич', 'SOL', 'c20218', 59.0786729, 42.2877245);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Чухлома', 'CHU', 'c20219', 58.7534246, 42.6883783);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Шарья', 'SHA', 'c10704', 58.3761832, 45.4060762);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Абинск', 'ABI', 'c20183', 44.8679931, 38.1618437);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Анапа', 'ANA', 'c1107', 44.8950777, 37.3163142);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Апшеронск', 'APS', 'c10986', 44.4585239, 39.7300092);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Армавир', 'ARM', 'c10987', 45.0010338, 41.132392);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Белореченск', 'BEL', 'c10988', 44.7652733, 39.8780457);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Геленджик', 'GEL', 'c10990', 44.5631053, 38.0790184);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Гулькевичи', 'GUL', 'c20675', 45.3605769, 40.6918484);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ейск', 'EYS', 'c10993', 46.7114611, 38.2764915);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кореновск', 'KOR', 'c20688', 45.4640868, 39.4590178);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Краснодар', 'KRR', 'c35', 45.040235, 38.9760801);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кропоткин', 'KRO', 'c10996', 45.4332464, 40.5727852);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Крымск', 'KRY', 'c10997', 44.9344108, 37.9855314);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Курганинск', 'KUG', 'c20702', 44.8876442, 40.5913858);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Лабинск', 'LAB', 'c21018', 44.6353153, 40.724385);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Новокубанск', 'NOX', 'c20231', 45.1038782, 41.0473679);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Новороссийск', 'NOV', 'c970', 44.7234264, 37.7687218);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Приморско-Ахтарск', 'PRI', 'c11000', 46.0515, 38.1704654);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Славянск-на-Кубани', 'SLA', 'c20704', 45.2605079, 38.1260725);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сочи', 'SOC', 'c239', 43.5855829, 39.7231419);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Темрюк', 'TEM', 'c20677', 45.2611082, 37.445519);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тимашевск', 'TIM', 'c21141', 45.6159358, 38.9350513);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тихорецк', 'TIH', 'c11002', 45.8546953, 40.1258702);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Туапсе', 'TUA', 'c1058', 44.1103707, 39.082645);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Усть-Лабинск', 'USL', 'c20693', 45.222676, 39.6930239);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Хадыженск', 'KHA', 'c24464', 44.412303, 39.5319151);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ачинск', 'ACH', 'c11302', 56.2538662, 90.47949);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Боготол', 'BOG', 'c20084', 56.209881, 89.5300182);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Бородино', 'BOR', 'c20085', 55.9054308, 94.9021138);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Дивногорск', 'DIV', 'c11303', 55.9577868, 92.380085);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Дудинка', 'DUD', 'c11344', 69.4031339, 86.1908135);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Енисейск', 'ENI', 'c11304', 58.4485234, 92.165237);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Заозерный', 'ZAO', 'c20087', 55.9617268, 94.7091037);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Игарка', 'IGA', 'c11305', 67.4667947, 86.5814287);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Иланский', 'ILS', 'c20089', 56.2374163, 96.0672656);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Канск', 'KAN', 'c11307', 56.2049776, 95.7051246);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кодинск', 'KOD', 'c20643', 58.6033961, 99.1797563);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Красноярск', 'KJA', 'c62', 56.009466, 92.8524162);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Лесосибирск', 'LES', 'c20090', 58.2218201, 92.5036986);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Минусинск', 'MIN', 'c11310', 53.7105509, 91.6871866);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Назарово', 'NAZ', 'c20091', 56.0113176, 90.4167947);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Норильск', 'NOR', 'c11311', 69.3490828, 88.2009965);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ужур', 'UZH', 'c20092', 55.3141977, 89.8333827);
# ...
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Плавск', 'PLA', 'c20662', 53.7095993, 37.2863144);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Суворов', 'SUV', 'c10831', 54.1345367, 36.4806933);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тула', 'TYU', 'c15', 54.192017, 37.6153885);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Узловая', 'UZL', 'c10833', 53.9731407, 38.1763104);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Чекалин', 'CHE', 'c24444', 54.0985105, 36.2474377);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Щекино', 'SCH', 'c33263', 54.0020749, 37.517686);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кызыл', 'KYZ', 'c11333', 51.7191542, 94.4377234);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Туран', 'TYA', 'c11335', 52.144932, 93.9172495);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Заводоуковск', 'ZAV', 'c20647', 56.5012193, 66.5505094);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ишим', 'ISH', 'c11173', 56.0952037, 69.4643292);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тобольск', 'TOX', 'c11175', 58.2016828, 68.2538392);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тюмень', 'TJM', 'c55', 57.1530824, 65.5343118);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ялуторовск', 'JAL', 'c11178', 56.649167, 66.297034);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Воткинск', 'VOT', 'c11149', 57.0517641, 53.9874635);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Глазов', 'GLA', 'c11150', 58.1359111, 52.6634998);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ижевск', 'IJK', 'c44', 56.8527444, 53.2113961);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Камбарка', 'KAM', 'c20072', 56.2659745, 54.1934153);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Можга', 'MOZ', 'c11151', 56.4427219, 52.2138882);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сарапул', 'SAR', 'c11152', 56.4616117, 53.8036967);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Барыш', 'BAR', 'c11154', 53.6534563, 47.1180805);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Димитровград', 'DGR', 'c11155', 54.2168446, 49.6261645);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Инза', 'INZ', 'c20069', 53.8550467, 46.3532786);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Новоульяновск', 'NUL', 'c20070', 54.1447691, 48.3911701);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сенгилей', 'SEN', 'c20071', 53.9590553, 48.7767869);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ульяновск', 'ULY', 'c195', 54.3080674, 48.3748717);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Амурск', 'AMS', 'c11451', 50.2345017, 136.8791135);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Бикин', 'BIK', 'c20165', 46.8186244, 134.2551046);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Вяземский', 'VYA', 'c20166', 47.5354416, 134.7553701);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Комсомольск-на-Амуре', 'KXN', 'c11453', 50.550011, 137.0079286);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Николаевск-на-Амуре', 'NIK', 'c11454', 53.1461943, 140.7109642);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Советская Гавань', 'SAI', 'c11456', 48.9664554, 140.2852223);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Хабаровск', 'KHV', 'c76', 48.4647991, 135.0598811);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Абаза', 'ABZ', 'c11339', 52.6517296, 90.0885929);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Абакан', 'ABA', 'c1095', 53.7223661, 91.4437792);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Саяногорск', 'SAY', 'c11341', 53.1008226, 91.4121643);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сорск', 'SOR', 'c20083', 54.0001451, 90.2595674);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Черногорск', 'CHE', 'c11342', 53.8258425, 91.3259669);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Когалым', 'KOG', 'c11180', 62.2638914, 74.4828687);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Лангепас', 'LAN', 'c11181', 61.2536667, 75.1807905);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Лянтор', 'LNT', 'c22454', 61.6391639, 72.1793828);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Мегион', 'MEG', 'c11182', 61.0318946, 76.1024772);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нефтеюганск', 'NEF', 'c11184', 61.0882837, 72.6164185);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нижневартовск', 'NJV', 'c1091', 60.9397379, 76.5696206);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нягань', 'NYA', 'c11186', 62.1454839, 65.3944361);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Покачи', 'POK', 'c11187', 61.7421977, 75.5942069);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Пыть-Ях', 'PYA', 'c11188', 60.7585769, 72.8366445);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Урай', 'URJ', 'c11192', 60.1295842, 64.8040117);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ханты-Мансийск', 'HMA', 'c57', 61.0024344, 69.0183322);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Югорск', 'UGR', 'c11177', 61.3124504, 63.3364787);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Аша', 'ASH', 'c11196', 54.9907105, 57.2783704);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Бакал', 'BAK', 'c22772', 54.9406759, 58.8051085);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Верхнеуральск', 'VER', 'c11199', 53.8760587, 59.2169071);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Верхний Уфалей', 'VFU', 'c11200', 56.0487252, 60.231963);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Еманжелинск', 'EME', 'c20666', 54.7554084, 61.3243985);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Златоуст', 'ZLT', 'c11202', 55.1715695, 59.6726264);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Карталы', 'KAR', 'c11203', 53.0536101, 60.647712);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Касли', 'KSL', 'c11204', 55.8868045, 60.7422529);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Катав-Ивановск', 'KAI', 'c11205', 54.7520187, 58.1983706);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Копейск', 'KOP', 'c11207', 55.1167545, 61.6180809);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Коркино', 'KOR', 'c11208', 54.8903023, 61.4034541);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Куса', 'KUS', 'c11209', 55.3385156, 59.4386474);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кыштым', 'KYS', 'c11210', 55.7060048, 60.5563271);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Магнитогорск', 'MGN', 'c235', 53.4071891, 58.9791432);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Миасс', 'MI', 'c11212', 55.0455774, 60.1077757);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Миньяр', 'MIN', 'c20617', 55.0709601, 57.5484435);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нязепетровск', 'NZP', 'c20632', 56.0537199, 59.6096791);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Пласт', 'PLS', 'c11216', 54.3691832, 60.8152305);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сатка', 'SAT', 'c11217', 55.0404497, 59.0288153);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Сим', 'SIM', 'c24470', 54.9906584, 57.6899045);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Снежинск', 'SNE', 'c11218', 56.085232, 60.7324989);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Трехгорный', 'TRE', 'c11219', 54.8178174, 58.4465039);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Усть-Катав', 'UST', 'c11223', 54.9261323, 58.1528067);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Чебаркуль', 'CHE', 'c11224', 54.9819329, 60.3773305);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Челябинск', 'CEK', 'c56', 55.1603659, 61.4007858);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Южноуральск', 'YUZ', 'c11227', 54.4490124, 61.2581869);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Юрюзань', 'YUR', 'c20759', 54.8546372, 58.4227116);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Аргун', 'ARG', 'c11025', 43.2918071, 45.8724383);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Грозный', 'GRV', 'c1106', 43.3179243, 45.6981102);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Гудермес', 'GCM', 'c11026', 43.3519164, 46.1036052);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Урус-Мартан', 'URM', 'c20699', 43.1276072, 45.5406838);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Шали', 'SHL', 'c61110', 43.148776, 45.9009577);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Алатырь', 'ALA', 'c20073', 54.8398179, 46.5721423);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Козловка', 'KZV', 'c20075', 55.8406526, 48.2579372);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Мариинский Посад', 'MRP', 'c20076', 56.111968, 47.7142676);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Новочебоксарск', 'CNK', 'c22865', 56.109486, 47.4791429);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Цивильск', 'TSV', 'c20077', 55.8650132, 47.472967);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Чебоксары', 'CSY', 'c45', 56.1439378, 47.2488718);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Шумерля', 'SHM', 'c20078', 55.4961795, 46.4183534);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ядрин', 'YAD', 'c20079', 55.9406826, 46.2020765);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Анадырь', 'DYR', 'c11458', 64.7314347, 177.5015752);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Певек', 'PWE', 'c11460', 69.7018051, 170.2999194);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Алдан', 'ADH', 'c11432', 58.6094885, 125.3816689);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Вилюйск', 'VYU', 'c11434', 63.7517314, 121.6272754);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нерюнгри', 'NER', 'c11437', 56.6600322, 124.72031);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Нюрба', 'NYR', 'c20614', 63.2828775, 118.324325);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Покровск', 'PKV', 'c20615', 61.4843538, 129.1482195);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Среднеколымск', 'SEK', 'c22220', 67.4581664, 153.7069511);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Томмот', 'TOF', 'c22978', 58.9586939, 126.2875375);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Якутск', 'YKS', 'c74', 62.0280273, 129.7325717);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Губкинский', 'GUB', 'c11228', 64.4456575, 76.4714559);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Лабытнанги', 'LAV', 'c22463', 66.6592376, 66.3882628);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Муравленко', 'NYR', 'c24473', 63.794188, 74.494913);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Надым', 'NYM', 'c11229', 65.5377514, 72.5182746);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Новый Уренгой', 'NUX', 'c11230', 66.0840036, 76.6810032);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ноябрьск', 'NOY', 'c11231', 63.201846, 75.4509665);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Салехард', 'SLY', 'c58', 66.5493568, 66.6083994);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тарко-Сале', 'TYM', 'c20255', 64.9117649, 77.7610204);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Гаврилов-Ям', 'GVR', 'c20257', 57.3091552, 39.8545157);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Данилов', 'DAN', 'c10835', 58.1859542, 40.1796765);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Любим', 'LYU', 'c20592', 58.3619868, 40.6869581);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Мышкин', 'MYA', 'c10836', 57.7881664, 38.4542816);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Переславль-Залесский', 'PER', 'c10837', 56.7360435, 38.8543064);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Пошехонье', 'POS', 'c20596', 58.506328, 39.1210034);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ростов', 'ROS', 'c10838', 57.2050177, 39.4378357);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Рыбинск', 'RYB', 'c10839', 58.0483802, 38.858338);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Тутаев', 'TUT', 'c21154', 57.8674237, 39.5368234);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Углич', 'UGL', 'c10840', 57.5223866, 38.3019793);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Ярославль', 'IAR', 'c16', 57.6216145, 39.897878);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кудрово', 'KUD', 'c43578', 59.906944, 30.505556);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Мурино', 'MUR', 'c43588', 60.04796, 30.45204);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Кукмор', 'KUK', 'c21930', 56.1855, 50.8944);
# INSERT INTO router.City(name, code, code_yandex, latitude, longitude) VALUES('Белоозёрский', 'BEO', 'c21632', 55.459619, 38.43892);

# %% [markdown]
# ## Команды

# %% [markdown]
# __1. Создание и заполнение БД__: `psql -U postgres -q -b -f create_db.sql`\
# __2. Проверка кодировки сервера__: `show server_encoding;`

# %% [markdown]
# __3. DB checks__
# ```SQL
# select *
# from router.city
# where lower(name) like 'мо%';
#
# select name, count(name) as dup_cnt
# from router.city c
# group by name
# having count(name) > 1;
#
# select * from router.city where name = 'Ялта';
#
# select count(*), (select count(*) from router.city)
# from (
# 	select *
# 	from router.city
# 	group by id, name, latitude, longitude
# ) as dedup;
# ```
