# %% [markdown]
# # Скрипт для создания и заполнения БД

# %% [markdown]
# ## Парсинг JSON и формирование sql скрипта

# %%
import json

# %%
DATABASE_OWNER = 'postgres' # Юзер БД (админ сервера)
ENCODING = 'UTF8' # Выбранная кодировка должна соответствовать кодировке сервера (на всякий случай)
LOCALE = 'ru_RU'

DATABASE_NAME = 'glemapanida'
SCHEMA_NAME = 'router'
TABLE_NAME = 'City'

# %%
create_db_q = f"""CREATE DATABASE {DATABASE_NAME} WITH
OWNER "{DATABASE_OWNER}"
ENCODING '{ENCODING}'
LC_COLLATE = '{LOCALE}.{ENCODING}'
LC_CTYPE = '{LOCALE}.{ENCODING}'
TEMPLATE template0;

\c {DATABASE_NAME};
set client_encoding TO '{ENCODING}';
"""

create_schema_table_q = f"""
CREATE SCHEMA {SCHEMA_NAME}
    CREATE TABLE {TABLE_NAME} (
        id SERIAL PRIMARY KEY,
        name TEXT NOT NULL,
        latitude NUMERIC(10, 7) NOT NULL,
        longitude NUMERIC(10, 7) NOT NULL
    );

CREATE INDEX name_idx ON {SCHEMA_NAME}.{TABLE_NAME} ((lower(name)));
"""

# %%
with open('cities.json', 'r', encoding=f'{ENCODING}') as f:
    city_data = json.load(f)

# %%
insert_into_table_q = f"""
"""

for city in city_data:
    city_name = list(city.keys())[0]
    city_lat = city[city_name]['latitude']
    city_lon = city[city_name]['longitude']
    
    insert_into_table_q += f"""INSERT INTO {SCHEMA_NAME}.{TABLE_NAME}(name, latitude, longitude) VALUES('{city_name}', {city_lat}, {city_lon});
"""

# %%
query_str = create_db_q + create_schema_table_q + insert_into_table_q

# %%
with open('create_db.sql', 'w', encoding=f'{ENCODING}') as f:
    f.write(query_str)

# %%
with open('create_db.sql', 'r', encoding=f'{ENCODING}') as f:
    print(f.read())
# Out:
# CREATE DATABASE glemapanida WITH
# OWNER "postgres"
# ENCODING 'UTF8'
# LC_COLLATE = 'ru_RU.UTF8'
# LC_CTYPE = 'ru_RU.UTF8'
# TEMPLATE template0;
#
# \c glemapanida;
# set client_encoding TO 'UTF8';
#
# CREATE SCHEMA router
#     CREATE TABLE City (
#         id SERIAL PRIMARY KEY,
#         name TEXT NOT NULL,
#         latitude NUMERIC(10, 7) NOT NULL,
#         longitude NUMERIC(10, 7) NOT NULL
#     );
#
# CREATE INDEX name_idx ON router.City ((lower(name)));
#
# INSERT INTO router.City(name, latitude, longitude) VALUES('Адыгейск', 44.8783715, 39.190172);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Майкоп', 44.6098268, 40.1006527);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Горно-Алтайск', 51.9582681, 85.9602957);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Алейск', 52.4920914, 82.7794145);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Барнаул', 53.3481145, 83.7798362);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Белокуриха', 51.9960534, 84.9840343);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Бийск', 52.5393683, 85.2138852);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Горняк', 50.9979032, 81.4643059);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Заринск', 53.7063495, 84.9314703);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Змеиногорск', 51.1580235, 82.1872476);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Камень-на-Оби', 53.7915454, 81.3545173);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Новоалтайск', 53.4120811, 83.9311249);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Рубцовск', 51.5013075, 81.2077729);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Славгород', 52.9993053, 78.6459674);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Яровое', 52.9251728, 78.5729898);
# INSERT INTO router.City(name, latitude, longitude) VALUES('

# INSERT INTO router.City(name, latitude, longitude) VALUES('Чебаркуль', 54.9819329, 60.3773305);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Челябинск', 55.1603659, 61.4007858);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Южноуральск', 54.4490124, 61.2581869);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Юрюзань', 54.8546372, 58.4227116);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Аргун', 43.2918071, 45.8724383);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Грозный', 43.3179243, 45.6981102);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Гудермес', 43.3519164, 46.1036052);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Урус-Мартан', 43.1276072, 45.5406838);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Шали', 43.148776, 45.9009577);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Алатырь', 54.8398179, 46.5721423);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Канаш', 55.5069543, 47.4917734);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Козловка', 55.8406526, 48.2579372);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Мариинский Посад', 56.111968, 47.7142676);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Новочебоксарск', 56.109486, 47.4791429);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Цивильск', 55.8650132, 47.472967);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Чебоксары', 56.1439378, 47.2488718);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Шумерля', 55.4961795, 46.4183534);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Ядрин', 55.9406826, 46.2020765);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Анадырь', 64.7314347, 177.5015752);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Билибино', 68.0585533, 166.4388451);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Певек', 69.7018051, 170.2999194);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Алдан', 58.6094885, 125.3816689);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Верхоянск', 67.5500865, 133.3907829);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Вилюйск', 63.7517314, 121.6272754);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Ленск', 60.7276036, 114.9549103);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Мирный', 62.5362511, 113.9668146);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Нерюнгри', 56.6600322, 124.72031);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Нюрба', 63.2828775, 118.324325);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Олекминск', 60.3758203, 120.406013);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Покровск', 61.4843538, 129.1482195);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Среднеколымск', 67.4581664, 153.7069511);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Томмот', 58.9586939, 126.2875375);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Удачный', 66.4072367, 112.3061653);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Якутск', 62.0280273, 129.7325717);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Губкинский', 64.4456575, 76.4714559);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Лабытнанги', 66.6592376, 66.3882628);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Муравленко', 63.794188, 74.494913);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Надым', 65.5377514, 72.5182746);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Новый Уренгой', 66.0840036, 76.6810032);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Ноябрьск', 63.201846, 75.4509665);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Салехард', 66.5493568, 66.6083994);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Тарко-Сале', 64.9117649, 77.7610204);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Гаврилов-Ям', 57.3091552, 39.8545157);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Данилов', 58.1859542, 40.1796765);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Любим', 58.3619868, 40.6869581);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Мышкин', 57.7881664, 38.4542816);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Переславль-Залесский', 56.7360435, 38.8543064);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Пошехонье', 58.506328, 39.1210034);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Ростов', 57.2050177, 39.4378357);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Рыбинск', 58.0483802, 38.858338);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Тутаев', 57.8674237, 39.5368234);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Углич', 57.5223866, 38.3019793);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Ярославль', 57.6216145, 39.897878);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Кудрово', 59.906944, 30.505556);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Мурино', 60.04796, 30.45204);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Курчалой', 43.2021, 46.09);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Кукмор', 56.1855, 50.8944);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Белоозёрский', 55.459619, 38.43892);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Ачхой-мартан', 43.18997, 45.28373);
# INSERT INTO router.City(name, latitude, longitude) VALUES('Колтуши', 59.92969, 30.64465);

# %% [markdown]
# ## Команды

# %% [markdown]
# __1. Создание и заполнение БД__: `psql -U postgres -q -b -f create_db.sql`\
# __2. Проверка кодировки сервера__: `show server_encoding;`

# %% [markdown]
# __3. DB checks__
# ```SQL
# select *
# from router.city
# where lower(name) like 'мо%';
#
# select name, count(name) as dup_cnt
# from router.city c
# group by name
# having count(name) > 1;
#
# select * from router.city where name = 'Ялта';
#
# select count(*), (select count(*) from router.city)
# from (
# 	select *
# 	from router.city
# 	group by id, name, latitude, longitude
# ) as dedup;
# ```
